# %% [markdown]
# #### Analyze text with Title/Abstract of clusters

# %%
import sys
# !{sys.executable} -m pip install umap-learn
# Out:
# Successfully installed llvmlite-0.36.0 numba-0.53.1 pynndescent-0.5.2 umap-learn-0.5.1

# %%
import sys
# !{sys.executable} -m pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.0.1-cp37-cp37m-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 27.8 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.18.1 in /home/hadoop/miniconda/lib/python3.7/site-packages (from gensim) (1.6.2)
# Requirement already satisfied: numpy>=1.11.3 in /home/hadoop/miniconda/lib/python3.7/site-packages (from gensim) (1.19.2)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.0.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 8.2 MB/s  eta 0:00:01
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-4.0.1 smart-open-5.0.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import umap

# %%
from sklearn.manifold import TSNE

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
from pyspark import SparkContext

import time 
from time import sleep

sc = SparkContext()
sc
# Out:
# <SparkContext master=yarn appName=pyspark-shell>

# %%
spark = SparkSession \
 .builder \
 .appName("Python Spark SQL basic example") \
 .config("spark.some.config.option", "some-value") \
 .getOrCreate()

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StringType,ArrayType

# %%
sample_seed_1_cluser_assinged = spark.read.parquet("s3://hids511final/corid_embedding_pca_200_sample_seed_01_1_KMEANS_PRED_doublechecksample.parquet")

# %%
sample_seed_1_cluser_assinged.sort("_c0", ascending=True).show()
# Out:
# +--------+--------------------+--------------------+--------+----------+
# |     _c0|           EMBEDDING|        pca_features|_c0_pred|prediction|
# +--------+--------------------+--------------------+--------+----------+
# |001skdgj|[1.01681923866271...|[-20.032345850624...|001skdgj|        10|
# |002f78jk|[-4.9741296768188...|[33.9081174277701...|002f78jk|        47|
# |00s30a1k|[-4.5005540847778...|[37.4830379244023...|00s30a1k|        47|
# |00t12unr|[-4.3244304656982...|[34.1231454835673...|00t12unr|        47|
# |00t12unr|[-4.3244304656982...|[34.1231454835673...|00t12unr|        47|
# |012ziqe8|[1.79250776767730...|[-13.160795297727...|012ziqe8|         8|
# |018bikme|[-7.9772782325744...|[34.3424758739515...|018bikme|        11|
# |01duo6hp|[-3.6498296260833...|[38.8432224449848...|01duo6hp|        26|
# |01lvglcd|[0.42638444900512...|[-15.320312025515...|01lvglcd|        12|
# |01xyjaih|[-5.9328069686889...|[41.2406117239674...|01xyjaih|        17|
# |01yq8d0k|[-0.0765987634658...|[20.4411396075078...|01yq8d0k|        31|
# |021rbjj7|[-0.9226173162460...|[-25.703408953223...|021rbjj7|        33|
# |023szxtw|[-1.5941321849822...|[-22.074171588345...|023szxtw|        10|
# |024w3wy3|[-3.2439620494842...|[33.6204891995136...|024w3wy3|        26|
# |02br9064|[-2.2767150402069...|[48.8235646987542...|02br9064|        34|
# |02mvpix3|[-3.0652477741241...|[40.3599716193349...|02mvpix3|        17|
# |02p8ug67|[-0.0651985406875...|[-24.259900216724...|02p8ug67|         6|
# |02wmt2e9|[-3.1434156894683...|[50.4241905812274...|02wmt2e9|        22|
# |02zv1gsq|[-1.2292095422744...|[35.4180741129871...|02zv1gsq|         3|
# |03366q9t|[-1.9931368827819...|[44.0388634512929...|03366q9t|        48|
# +--------+--------------------+--------------------+--------+----------+
# only showing top 20 rows

# %%
metadata = spark.read.csv('s3://ai2-semanticscholar-cord-19/2021-04-19/metadata.csv/',header = True)

# %%
metadata.columns
# Out:
# ['cord_uid',
#  'sha',
#  'source_x',
#  'title',
#  'doi',
#  'pmcid',
#  'pubmed_id',
#  'license',
#  'abstract',
#  'publish_time',
#  'authors',
#  'journal',
#  'mag_id',
#  'who_covidence_id',
#  'arxiv_id',
#  'pdf_json_files',
#  'pmc_json_files',
#  'url',
#  's2_id']

# %%
metadata[['cord_uid','title','abstract','authors','journal','publish_time']].show()
# Out:
# +--------+--------------------+--------------------+--------------------+--------------------+------------+
# |cord_uid|               title|            abstract|             authors|             journal|publish_time|
# +--------+--------------------+--------------------+--------------------+--------------------+------------+
# |ug7v899j|Clinical features...|OBJECTIVE: This r...|Madani, Tariq A; ...|      BMC Infect Dis|  2001-07-04|
# |02tnwd4m|Nitric oxide: a p...|Inflammatory dise...|Vliet, Albert van...|          Respir Res|  2000-08-15|
# |ejv2xln0|Surfactant protei...|Surfactant protei...|     Crouch, Erika C|          Respir Res|  2000-08-25|
# |2b73a28n|Role of endotheli...|Endothelin-1 (ET-...|Fagan, Karen A; M...|          Respir Res|  2001-02-22|
# |9785vg6d|Gene expression i...|Respiratory syncy...|Domachowske, Jose...|          Respir Res|  2001-05-11|
# |zjufx4fo|Sequence requirem...|Nidovirus subgeno...|Pasternak, Alexan...|    The EMBO Journal|  2001-12-17|
# |5yhe786e|Debate: Transfusi...|Recent evidence s...|Alvarez, Gonzalo;...|           Crit Care|  2001-03-08|
# |8zchiykl|The 21st Internat...|The 21st Internat...|Ball, Jonathan; V...|           Crit Care|  2001-05-02|
# |8qnrcgnk|Heme oxygenase-1 ...|Heme oxygenase-1 ...|Slebos, Dirk-Jan;...|          Respir Res|  2003-08-07|
# |jg13scgo|Technical Descrip...|This report descr...|Tsui, Fu-Chiang; ...|Journal of the Am...|  2003-09-01|
# |5tkvsudh|Conservation of p...|Regulation of orn...|Ivanov, Ivaylo P....|              EMBO J|  2000-04-17|
# |6lvn10f4|Heterogeneous nuc...|Heterogeneous nuc...|Shi, Stephanie T....|    The EMBO Journal|  2000-09-01|
# |tvxpckxo|A Method to Ident...|The UBA domain is...|Pridgeon, Julia W...|  Biol Proced Online|  2003-12-12|
# |mcuixluu|Vaccinia virus in...|We examined the r...|Ploubidou, Aspasi...|    The EMBO Journal|  2000-08-01|
# |6iu1dtyl|The site of origi...|                null|       Barry, John M|        J Transl Med|  2004-01-20|
# |t35n7bk9|Multi-faceted, mu...|There are hundred...|Shieh, Biehuoy; L...|       Retrovirology|  2004-05-26|
# |eiqypt0m|Herpes simplex vi...|INTRODUCTION: The...|Verheij, Joanne; ...|           Crit Care|  2004-03-31|
# |sgmk96vr|Logistics of comm...|BACKGROUND: Previ...|Porco, Travis C; ...|   BMC Public Health|  2004-08-06|
# |di0fcy0j|Protection of pul...|BACKGROUND: Oxyge...|Kremer, Ted M; Ri...|          Respir Res|  2004-09-27|
# |4k8f7ou1|Bioinformatic map...|BACKGROUND: AlkB-...|Bratlie, Marit S;...|        BMC Genomics|  2005-01-03|
# +--------+--------------------+--------------------+--------------------+--------------------+------------+
# only showing top 20 rows

# %%
sample_seed_1_cluser_assinged_metadata= sample_seed_1_cluser_assinged.join(metadata[['cord_uid','title','abstract','authors','journal','publish_time']],
                                                   sample_seed_1_cluser_assinged["_c0"] == metadata["cord_uid"],"left")

# %%
sample_seed_1_cluser_assinged_metadata.show()
# Out:
# +--------+--------------------+--------------------+--------+----------+--------+--------------------+--------------------+--------------------+--------------------+------------+
# |     _c0|           EMBEDDING|        pca_features|_c0_pred|prediction|cord_uid|               title|            abstract|             authors|             journal|publish_time|
# +--------+--------------------+--------------------+--------+----------+--------+--------------------+--------------------+--------------------+--------------------+------------+
# |1qswwxw8|[-5.6927232742309...|[15.6444404052320...|1qswwxw8|        15|1qswwxw8|Design of a Web-b...|It is important t...|   Xue, C.; Zeng, X.|2020 3rd Internat...|        2020|
# |5vvl0npo|[-2.3355121612548...|[47.8782494955001...|5vvl0npo|        28|5vvl0npo|Clinical Misdiagn...|BACKGROUND: Simil...|Eshaghi, Hamid; Z...| Case Rep Infect Dis|  2021-03-31|
# |5wraup2d|[1.34078013896942...|[-0.0133305518779...|5wraup2d|        32|5wraup2d|                null|The COVID19 crisi...|Rousseau, Aurélie...|      Sante publique|  2020-09-15|
# |5wraup2d|[1.34078013896942...|[-0.0133305518779...|5wraup2d|        32|5wraup2d|                null|The COVID19 crisi...|Rousseau, Aurélie...|      Sante publique|  2020-09-15|
# |5wraup2d|[1.34078013896942...|[-0.0133305518779...|5wraup2d|        32|5wraup2d|                null|The COVID19 crisi...|Rousseau, Aurélie...|      Sante publique|  2020-09-15|
# |5wraup2d|[1.34078013896942...|[-0.0133305518779...|5wraup2d|        32|5wraup2d|                null|The COVID19 crisi...|Rousseau, Aurélie...|      Sante publique|  2020-09-15|
# |76fftal3|[-3.1268446445465...|[41.1048164608631...|76fftal3|        27|76fftal3|Persistent sympto...|BACKGROUND: Many ...|Goërtz, Yvonne M....|        ERJ Open Res|  2020-09-11|
# |7zo4o617|[-1.1468764543533...|[39.6879685406620...|7zo4o617|        40|7zo4o617|Evaluation of lef...|AIMS Heart failur...|Hellwig, Simon; G...|   ESC heart failure|  2020-07-15|
# |85lg00a8|[1.17229330539703...|[-15.468575662867...|85lg00a8|         6|85lg00a8|Contrôle des épid...|                null|Musa, Hassan H.; ...|Ethics Med Public...|  2020-07-04|
# |86w7qwbz|[0.36785805225372...|[-29.887670905835...|86w7qwbz|         1|86w7qwbz|Erratum: Vol. 69,...|                null|                null|MMWR Morb Mortal ...|        2020|
# |86w7qwbz|[0.36785805225372...|[-29.887670905835...|86w7qwbz|         1|86w7qwbz|Erratum: Vol. 69,...|                null|                null|MMWR Morb Mortal ...|        2020|
# |86w7qwbz|[0.36785805225372...|[-29.887670905835...|86w7qwbz|         1|86w7qwbz|Erratum: Vol. 69,...|                null|                null|MMWR Morb Mortal ...|        2020|
# |86w7qwbz|[0.36785805225372...|[-29.887670905835...|86w7qwbz|         1|86w7qwbz|Erratum: Vol. 69,...|                null|                null|MMWR Morb Mortal ...|        2020|
# |9fp80ujt|[2.01924157142639...|[-25.687166430257...|9fp80ujt|        10|9fp80ujt|Commentary: Prepa...|                null|           Levy, Gal|J Thorac Cardiova...|        2020|
# |9fp80ujt|[2.01924157142639...|[-25.687166430257...|9fp80ujt|        10|9fp80ujt|Commentary: Prepa...|                null|           Levy, Gal|J Thorac Cardiova...|        2020|
# |9fp80ujt|[2.01924157142639...|[-25.687166430257...|9fp80ujt|        10|9fp80ujt|Commentary: Prepa...|                null|           Levy, Gal|J Thorac Cardiova...|        2020|
# |9fp80ujt|[2.01924157142639...|[-25.687166430257...|9fp80ujt|        10|9fp80ujt|Commentary: Prepa...|                null|           Levy, Gal|J Thorac Cardiova...|        2020|
# |9gtnsyts|[-2.3152122497558...|[39.8263302110044...|9gtnsyts|         5|9gtnsyts|Awareness, Attitu...|BACKGROUND: The e...|Wolf, Michael S.;...|      Ann Intern Med|  2020-04-09|
# |9wqhlqcx|[-0.1847341209650...|[28.4932868369235...|9wqhlqcx|         5|9wqhlqcx|Emergency remote ...|The coronavirus d...|Misirli, Ozge; Er...|Educ Inf Technol ...|  2021-03-29|
# |aunut5gj|[-3.9553184509277...|[27.9731779539831...|aunut5gj|         9|aunut5gj|Relationship of G...|BACKGROUND: Prote...|Valentine, Randal...|J Public Health (...|  2020-08-05|
# +--------+--------------------+--------------------+--------+----------+--------+--------------------+--------------------+--------------------+--------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ### From TSNE sample --

# %%
#for cmap in c_map_opt:

ax = TSNE_2d.plot.scatter(x=0,y=1,c='cluster', cmap='Paired', s=30,figsize=(40,20))


for i, txt in enumerate(TSNE_2d.groupby('cluster').first().reset_index().values):
    ax.annotate(txt[0], (txt[1], txt[2]),fontsize=22)
    
plt.show()
plt.close()

# %% [markdown]
# #### Which clusters had the most publications in 2021? or (Of papers published in 2021, what is their distirbution across clusters)

# %%
sample_seed_1_cluser_assinged_metadata.distinct().filter(sample_seed_1_cluser_assinged_metadata.publish_time.contains('2021')).groupBy("prediction").count().sort('count',ascending=False).show()
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|   70|
# |        27|   46|
# |        29|   45|
# |        11|   44|
# |        26|   42|
# |        24|   41|
# |        23|   40|
# |         7|   38|
# |        17|   38|
# |        13|   37|
# |        47|   37|
# |        34|   36|
# |        48|   35|
# |         8|   34|
# |         4|   34|
# |        39|   33|
# |        33|   33|
# |         5|   33|
# |        37|   32|
# |        41|   30|
# +----------+-----+
# only showing top 20 rows

# %% [markdown]
# #### What are the documents that make up cluster 33 like?

# %%
sample_seed_1_cluser_assinged_metadata.where(sample_seed_1_cluser_assinged_metadata.prediction == 33).show()
# Out:
# +--------+--------------------+--------------------+--------+----------+--------+--------------------+--------+--------------------+--------------------+------------+
# |     _c0|           EMBEDDING|        pca_features|_c0_pred|prediction|cord_uid|               title|abstract|             authors|             journal|publish_time|
# +--------+--------------------+--------------------+--------+----------+--------+--------------------+--------+--------------------+--------------------+------------+
# |2mmboxkn|[0.36178261041641...|[-27.227338505321...|2mmboxkn|        33|2mmboxkn|Could severe COVI...|    null|Chatzidionysiou, ...|                null|        2020|
# |2mmboxkn|[0.36178261041641...|[-27.227338505321...|2mmboxkn|        33|2mmboxkn|Could severe COVI...|    null|Chatzidionysiou, ...|                null|        2020|
# |2mmboxkn|[0.36178261041641...|[-27.227338505321...|2mmboxkn|        33|2mmboxkn|Could severe COVI...|    null|Chatzidionysiou, ...|                null|        2020|
# |2mmboxkn|[0.36178261041641...|[-27.227338505321...|2mmboxkn|        33|2mmboxkn|Could severe COVI...|    null|Chatzidionysiou, ...|                null|        2020|
# |hentmh49|[-2.5299277305603...|[-27.086629466424...|hentmh49|        33|hentmh49|Otology and Neuro...|    null|  Lustig, Lawrence R|Otology & neuroto...|  2020-10-01|
# |htqubzlu|[0.36470350623130...|[-22.508701991748...|htqubzlu|        33|htqubzlu|Lactate dehydroge...|    null|Chen, Xiao-Yun; H...|           Crit Care|        2020|
# |htqubzlu|[0.36470350623130...|[-22.508701991748...|htqubzlu|        33|htqubzlu|Lactate dehydroge...|    null|Chen, Xiao-Yun; H...|           Crit Care|        2020|
# |htqubzlu|[0.36470350623130...|[-22.508701991748...|htqubzlu|        33|htqubzlu|Lactate dehydroge...|    null|Chen, Xiao-Yun; H...|           Crit Care|        2020|
# |htqubzlu|[0.36470350623130...|[-22.508701991748...|htqubzlu|        33|htqubzlu|Lactate dehydroge...|    null|Chen, Xiao-Yun; H...|           Crit Care|        2020|
# |ww61l24y|[-0.6912907361984...|[-27.104770354869...|ww61l24y|        33|ww61l24y|Acute Parotitis a...|    null|Riad, Abanoub; Ka...|       Oral diseases|  2020-07-25|
# |ooy5nail|[-1.0782053470611...|[-20.351588417468...|ooy5nail|        33|ooy5nail|Antithyroid arthr...|    null|Ghosh, Ritwik; Du...|Diabetes Metab Syndr|        2021|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |fhyrt8t8|[-0.4243046641349...|[-24.793248933721...|fhyrt8t8|        33|fhyrt8t8|Risk factors in p...|    null|Zhan, Ke; Liao, S...|                 Gut|        2020|
# |ohq1cbc1|[-1.2211281061172...|[-27.654078202327...|ohq1cbc1|        33|ohq1cbc1|Reliable Postmort...|    null|Cittadini, France...|Am J Forensic Med...|        2020|
# +--------+--------------------+--------------------+--------+----------+--------+--------------------+--------+--------------------+--------------------+------------+
# only showing top 20 rows

# %%
sample_seed_1_cluser_assinged_metadata.where(sample_seed_1_cluser_assinged_metadata.prediction == 33).count() ## Revise sampling
# Out:
# 292

# %%
sample_seed_1_cluser_assinged_metadata.where(sample_seed_1_cluser_assinged_metadata.prediction == 33).distinct().count()
# Out:
# 178

# %%
sample_seed_1_cluser_assinged_metadata.where(sample_seed_1_cluser_assinged_metadata.prediction == 33).distinct().groupBy("journal").count().sort('count',ascending=False).show()
# Out:
# +--------------------+-----+
# |             journal|count|
# +--------------------+-----+
# |                null|   12|
# |Lancet Diabetes E...|    5|
# |      Ann Intern Med|    5|
# |    Reactions Weekly|    4|
# |                 BMJ|    4|
# |           Crit Care|    3|
# |        Br J Anaesth|    2|
# |J Heart Lung Tran...|    2|
# |          Thromb Res|    2|
# |         Gastro-News|    2|
# | Am J Obstet Gynecol|    2|
# |     Am J Ophthalmol|    2|
# |                 Gut|    2|
# |        Neurosurgery|    2|
# |           Neurology|    2|
# |Aliment Pharmacol...|    2|
# |  Intensive Care Med|    2|
# |Mediterr J Hemato...|    2|
# |J Allergy Clin Im...|    2|
# |Am. j. respir. cr...|    2|
# +--------------------+-----+
# only showing top 20 rows

# %%
sample_seed_1_cluser_assinged_metadata.distinct().groupBy("publish_time").count().sort('count',ascending=False).show()
# Out:
# +------------+-----+
# |publish_time|count|
# +------------+-----+
# |        2020| 2215|
# |        2021|  632|
# |        null|  154|
# |        2015|   47|
# |        2016|   38|
# |        2018|   38|
# |        2017|   36|
# |        2014|   35|
# |        2019|   31|
# |        2013|   25|
# |  2020-09-01|   23|
# |        2010|   22|
# |  2020-07-01|   21|
# |  2021-03-01|   20|
# |  2020-10-01|   19|
# |        2008|   17|
# |  2020-06-22|   17|
# |        2011|   16|
# |  2021-02-01|   15|
# |        2007|   15|
# +------------+-----+
# only showing top 20 rows

# %%
sample_seed_1_cluser_assinged_metadata.distinct().filter(sample_seed_1_cluser_assinged_metadata.publish_time.contains('2021')).groupBy("prediction").count().sort('count',ascending=False).show()
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|   70|
# |        27|   46|
# |        29|   45|
# |        11|   44|
# |        26|   42|
# |        24|   41|
# |        23|   40|
# |         7|   38|
# |        17|   38|
# |        13|   37|
# |        47|   37|
# |        34|   36|
# |        48|   35|
# |         8|   34|
# |         4|   34|
# |        39|   33|
# |        33|   33|
# |         5|   33|
# |        37|   32|
# |        41|   30|
# +----------+-----+
# only showing top 20 rows

# %% [markdown]
# ### Pull All documents from Topic 33

# %%
cluster_of_interest = 33

# %%
sample_seed_1_cluser_assinged_metadata.where(sample_seed_1_cluser_assinged_metadata.prediction == cluster_of_interest).distinct().groupBy("publish_time").count().sort('count',ascending=False).show()
# Out:
# +------------+-----+
# |publish_time|count|
# +------------+-----+
# |        2020|   72|
# |        2021|   19|
# |        null|    5|
# |  2020-05-01|    3|
# |  2020-10-01|    2|
# |  2020-05-15|    2|
# |  2020-07-25|    2|
# |  2020-08-28|    2|
# |        2018|    2|
# |  2020-05-20|    2|
# |  2020-05-26|    2|
# |  2020-06-03|    2|
# |  2020-07-29|    2|
# |  2020-09-12|    1|
# |        2012|    1|
# |  2020-07-12|    1|
# |  2020-08-09|    1|
# |        2016|    1|
# |  2020-09-11|    1|
# |  2020-10-21|    1|
# +------------+-----+
# only showing top 20 rows

# %%
sample_seed_1_cluser_assinged_metadata_DF = sample_seed_1_cluser_assinged_metadata.where(sample_seed_1_cluser_assinged_metadata.prediction == cluster_of_interest).distinct().toPandas()

# %%
sample_seed_1_cluser_assinged_metadata_DF

# %%
time_flag = []
for i in sample_seed_1_cluser_assinged_metadata_DF['publish_time'].values:
    try:
        if '20' in i: 
            time_flag.append(1)
        else:
            time_flag.append(0)
    except:
        time_flag.append(0)
sample_seed_1_cluser_assinged_metadata_DF['time_flag'] = time_flag

# %%
sample_seed_1_cluser_assinged_metadata_DF['time_flag'] = time_flag

# %%
sample_seed_1_cluser_assinged_metadata_DF['publish_time'].value_counts().head(60)
# Out:
# 2020          72
# 2021          19
# 2020-05-01     3
# 2018           2
# 2020-05-20     2
# 2020-06-03     2
# 2020-07-25     2
# 2020-10-01     2
# 2020-08-28     2
# 2020-07-29     2
# 2020-05-26     2
# 2020-05-15     2
# 2020-10-06     1
# 2020-06-19     1
# 2020-09-12     1
# 2020-08-21     1
# 2020-12-31     1
# 2003           1
# 2020-04-10     1
# 2020-08-09     1
# 2020-05-10     1
# 2021-02-26     1
# 2021-03-27     1
# 2020-04-18     1
# 2014           1
# 2021-01-23     1
# 2020-04-15     1
# 2020-11-19     1
# 1999           1
# 2020-05-28     1
# 2016           1
# 2021-01-16     1
# 2020-03-19     1
# 2020-07-22     1
# 2020-08-03     1
# 2020-11-05     1
# 2021-04-13     1
# 2021-03-03     1
# 2020-04-08     1
# 2021-02-28     1
# 2020-09-11     1
# 2020-09-08     1
# 2015           1
# 2020-02-07     1
# 2020-09-09     1
# 2021-02-06     1
# 2020-11-12     1
# 2020-06-01     1
# 2021-02-17     1
# 2020-07-12     1
# 2020-04-21     1
# 2012           1
# 2020-02-24     1
# 2021-04-01     1
# 2020-09-19     1
# 2020-10-02     1
# 2021-01-09     1
# 2020-08-27     1
# 2020-06-22     1
# 2021-03-19     1
# Name: publish_time, dtype: int64

# %%
sample_seed_1_cluser_assinged_metadata_DF.loc[sample_seed_1_cluser_assinged_metadata_DF['time_flag']==1]
# Out:
#           _c0                                          EMBEDDING  \
# 0    2mmboxkn  [0.36178261041641235, -5.280364036560059, 3.44...
# 1    hentmh49  [-2.5299277305603027, -4.559889793395996, 3.89...
# 2    htqubzlu  [0.364703506231308, -8.41827392578125, 3.17150...
# 3    ww61l24y  [-0.6912907361984253, -4.919369697570801, 4.63...
# 4    ooy5nail  [-1.0782053470611572, -5.826241493225098, 6.09...
# ..        ...                                                ...
# 173  rgcpc1wt  [-0.5268262624740601, -5.849046230316162, 3.69...
# 174  s3sw4n60  [-1.2842167615890503, -6.548439979553223, 5.32...
# 175  x8kxndsv  [-3.505152940750122, -4.7609333992004395, 2.97...
# 176  7gifel0q  [0.626914381980896, -6.34467887878418, 3.43363...
# 177  ooguzd3y  [-0.4371323585510254, -5.448677062988281, 2.33...
#
#                                           pca_features  _c0_pred  prediction  \
# 0    [-27.227338505321494, 41.83335023601186, -14.7...  2mmboxkn          33
# 1    [-27.086629466424046, 32.54907978428423, -21.8...  hentmh49          33
# 2    [-22.50870199174873, 40.26119939886566, -27.63...  htqubzlu          33
# 3    [-27.104770354869697, 41.1541554609186, -21.64...  ww61l24y          33
# 4    [-20.3515884174686, 54.60307018500557, -28.893...  ooy5nail          33
# ..                                                 ...       ...         ...
# 173  [-22.859199816949474, 51.89082064225497, -21.7...  rgcpc1wt          33
# 174  [-29.705039127810412, 45.36251727428162, -26.0...  s3sw4n60          33
# 175  [-33.79551159498131, 20.036018947493304, -26.7...  x8kxndsv          33
# 176  [-29.560232734426677, 34.187624864033346, -18....  7gifel0q          33
# 177  [-30.86395092232955, 33.44693137014356, -10.21...  ooguzd3y          33
#
#      cord_uid                                              title abstract  \
# 0    2mmboxkn  Could severe COVID-19 be considered a compleme...     None
# 1    hentmh49  Otology and Neurotology in a Post-COVID-19 World.     None
# 2    htqubzlu  Lactate dehydrogenase elevations is associated...     None
# 3    ww61l24y     Acute Parotitis as a Presentation of COVID-19?     None
# 4    ooy5nail  Antithyroid arthritis syndrome in a case of po...     None
# ..        ...                                                ...      ...
# 173  rgcpc1wt  Pneumatocele and cysts in a patient with SARS-...     None
# 174  s3sw4n60  Radiology-pathology Correlation in Recovered C...     None
# 175  x8kxndsv  Repeated proning in non-intubated patients wit...     None
# 176  7gifel0q  Pharmacotherapeutic Modifications in Cardiopul...    Null.
# 177  ooguzd3y  Smell/Taste alteration in COVID-19 may reflect...     None
#
#                                                authors  \
# 0    Chatzidionysiou, Katerina; Svenungsson, Elisab...
# 1                                   Lustig, Lawrence R
# 2    Chen, Xiao-Yun; Huang, Ming-Yao; Xiao, Zheng-W...
# 3    Riad, Abanoub; Kassem, Islam; Badrah, Mai; Klu...
# 4    Ghosh, Ritwik; Dubey, Souvik; Sarkar, Anupam; ...
# ..                                                 ...
# 173  Brahmbhatt, Nishal; Tamimi, Omar; Ellison, Hen...
# 174  Pogatchnik, Brian P; Swenson, Kai E; Sharifi, ...
# 175  Jones, Jennifer R A; Attard, Zachary; Bellomo,...
# 176                                  Khan, Imran Ahmad
# 177                                   Propper, Ruth E.
#
#                                                journal publish_time  time_flag
# 0                                                 None         2020          1
# 1    Otology & neurotology : official publication o...   2020-10-01          1
# 2                                            Crit Care         2020          1
# 3                                        Oral diseases   2020-07-25          1
# 4                                 Diabetes Metab Syndr         2021          1
# ..                                                 ...          ...        ...
# 173                                         JTCVS Tech   2020-08-21          1
# 174                      Am. j. respir. crit. care med         2020          1
# 175                                        Respirology         2021          1
# 176                         J Coll Physicians Surg Pak         2020          1
# 177     Journal of Clinical Biochemistry and Nutrition         2021          1
#
# [172 rows x 12 columns]

# %%
sample_seed_1_cluser_assinged_metadata_DF['publish_time']= pd.to_datetime(sample_seed_1_cluser_assinged_metadata_DF['publish_time'])

# %%
sample_seed_1_cluser_assinged_metadata_DF['publish_time'].value_counts().plot.line(figsize=(20,5),title = 'Cluster 33 - Publish Time Distribution > 2020 (2020 publish time date issue)')
plt.show()

# %%
sample_seed_1_cluser_assinged_metadata_DF.loc[sample_seed_1_cluser_assinged_metadata_DF['publish_time']>'2020-01-01']['publish_time'].value_counts().plot.line(figsize=(20,5),title='Cluster 33 - Publish Time Distribution > 2020 ')
plt.show()

# %%
sample_seed_1_cluser_assinged_metadata_DF['publish_time'].value_counts().head(2)
# Out:
# 2020-01-01    72
# 2021-01-01    19
# Name: publish_time, dtype: int64

# %%
import gensim
gensim.__version__
# Out:
# '4.0.1'

# %% [markdown]
# #### LSI Background
# LSI provides both positive and negative weights per topic. A positive weight means the word is highly representative of a topic, while a negative weight means the word is highly unrepresentative of a topic (the less it occurs in a text, the more likely the topic).

# %%
from collections import defaultdict
from gensim import corpora
from gensim.parsing.preprocessing import remove_stopwords
from gensim import models

# %%
def tfidf_model(sample_seed_1_cluser_assinged_metadata_DF):
    title_courpus = sample_seed_1_cluser_assinged_metadata_DF['title'].dropna().drop_duplicates().values
    abstract_corpus = sample_seed_1_cluser_assinged_metadata_DF['abstract'].dropna().drop_duplicates().values
    total_documents = np.concatenate((title_courpus,abstract_corpus),axis=0)
    
    print('TOTAL CORPUS SHAPE:', total_documents.shape)
    total_documents_stopwords = [remove_stopwords(i) for i in list(total_documents) ]
    
    texts = [
    [word for word in document.lower().split() ]
    for document in total_documents_stopwords
    ]

    dictionary = corpora.Dictionary(texts)
    corpus = [dictionary.doc2bow(text) for text in texts]
    
    tfidf = models.TfidfModel(corpus)
    
    corpus_tfidf = tfidf[corpus]
    #for doc in corpus_tfidf:
    #    print(doc)
    


    return tfidf_model, corpus_tfidf, dictionary, corpus 

def lsi_model_train(corpus_tfidf,dictionary,num_topics):
    lsi_model = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=num_topics)
    corpus_lsi = lsi_model[corpus_tfidf]
    print('TERMS IN LSI:',lsi_model.num_terms)
    
    
    return lsi_model, corpus_lsi

def plot_lsi_terms(lsi_model_temp,num_terms_visible,figsize=(20,30)):
    
    
    fig, axs = plt.subplots(lsi_model_temp.num_topics,figsize=figsize)
    fig.suptitle('LSI Term Weights per Topic across {} Topics'.format(lsi_model_temp.num_topics))
    
    for topic_num in range(lsi_model_temp.num_topics):
        term_df = pd.DataFrame([i.replace('"','').split('*') for i in lsi_model_temp.print_topic(topic_num,topn=num_terms_visible).split('+')]).rename(columns={0:'weight',1:'term'}).set_index('term')
        term_df['weight'] = term_df['weight'].astype(float)

        #axs[topic_num] = term_df.plot.barh(title='TOPIC {}'.format(topic_num))
        if lsi_model_temp.num_topics == 1:
            term_df.sort_values('weight').plot.barh(title='TOPIC {}'.format(topic_num),ax=axs)
        else:
            term_df.sort_values('weight').plot.barh(title='TOPIC {}'.format(topic_num),ax=axs[topic_num])

    plt.show()
    plt.close()

# %%
tfidf_model, corpus_tfidf, dictionary, corpus  = tfidf_model(sample_seed_1_cluser_assinged_metadata_DF)

lsi_model, corpus_lsi = lsi_model_train(corpus_tfidf,dictionary,num_topics= 1) 

plot_lsi_terms(lsi_model,20,figsize=(10,10))
# Out:
# TOTAL CORPUS SHAPE: (167,)
# TERMS IN LSI: 886

# %%
lsi_model.num_topics
# Out:
# 1

# %%
title_courpus = sample_seed_1_cluser_assinged_metadata_DF['title'].dropna().drop_duplicates().values

# %%
abstract_corpus = sample_seed_1_cluser_assinged_metadata_DF['abstract'].dropna().drop_duplicates().values

# %%
total_documents = np.concatenate((title_courpus,abstract_corpus),axis=0)

# %%
total_documents.shape
# Out:
# (167,)

# %%
total_documents_stopwords = [remove_stopwords(i) for i in list(total_documents) ]

# %%
texts = [
    [word for word in document.lower().split() ]
    for document in total_documents_stopwords
]

dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
from gensim import models

tfidf = models.TfidfModel(corpus)  # step 1 -- initialize a model

# %%
corpus_tfidf = tfidf[corpus]
for doc in corpus_tfidf:
    print(doc)
# Out:
# [(0, 0.5305187897555039), (1, 0.5305187897555039), (2, 0.5305187897555039), (3, 0.07759245346984557), (4, 0.38681888825857025)]
# [(5, 0.5165716904320445), (6, 0.5165716904320445), (7, 0.4466106424308986), (8, 0.5165716904320445)]
# [(9, 0.3099878304937022), (10, 0.2635012132630893), (11, 0.4251456525631788), (12, 0.4251456525631788), (13, 0.4251456525631788), (14, 0.4251456525631788), (15, 0.33388523774075896)]
# [(16, 0.3805047095927925), (17, 0.5061805059210782), (18, 0.5854731051283801), (19, 0.5061805059210782)]
# [(7, 0.3695786200198646), (20, 0.4274726895267451), (21, 0.4274726895267451), (22, 0.23515275350447684), (23, 0.4274726895267451), (24, 0.2778186908373147), (25, 0.4274726895267451)]
# [(3, 0.06429962399591498), (4, 0.32055062003175266), (26, 0.43963242787913176), (27, 0.3800915239554422), (28, 0.43963242787913176), (29, 0.3452623279010426), (30, 0.32055062003175266), (31, 0.1446551013432895), (32, 0.3452623279010426)]
# [(3, 0.06178826379700498), (33, 0.3652462314656232), (34, 0.3317773646214941), (35, 0.2896115791062771), (36, 0.42246163724440017), (37, 0.42246163724440017), (38, 0.42246163724440017), (39, 0.3652462314656232)]
# [(10, 0.2482000773444501), (29, 0.3144970028987521), (30, 0.5839745673395169), (31, 0.1317653046686256), (40, 0.40045805687991826), (41, 0.40045805687991826), (42, 0.40045805687991826)]
# [(3, 0.06537928977315358), (43, 0.38647370452090285), (44, 0.38647370452090285), (45, 0.38647370452090285), (46, 0.2905190203569497), (47, 0.3510596855905397), (48, 0.32593303928731293), (49, 0.38647370452090285), (50, 0.2905190203569497)]
# [(51, 0.40258946741330004), (52, 0.40258946741330004), (53, 0.40258946741330004), (54, 0.26164684089053836), (55, 0.40258946741330004), (56, 0.3480654166839601), (57, 0.40258946741330004)]
# [(3, 0.08414246411207577), (58, 0.5753028320612685), (59, 0.5753028320612685), (60, 0.5753028320612685)]
# [(61, 0.36877163943676855), (62, 0.26436498036939055), (63, 0.2434201564145831), (64, 0.42653929635526416), (65, 0.42653929635526416), (66, 0.42653929635526416), (67, 0.33497972638492357), (68, 0.277212069466428)]
# [(69, 0.3383694827545453), (70, 0.40122016406472727), (71, 0.3644548723534948), (72, 0.40122016406472727), (73, 0.4640708453749092), (74, 0.4640708453749092)]
# [(3, 0.05621610238977293), (75, 0.3843633919397082), (76, 0.3843633919397082), (77, 0.3843633919397082), (78, 0.3843633919397082), (79, 0.3843633919397082), (80, 0.33230776014369007), (81, 0.3843633919397082)]
# [(3, 0.062172447593050365), (9, 0.3099460834500382), (15, 0.3338402723575163), (47, 0.3338402723575163), (82, 0.3675172401503265), (83, 0.4250883968506147), (84, 0.4250883968506147), (85, 0.4250883968506147)]
# [(3, 0.07267989957220569), (35, 0.3406624363737571), (56, 0.42962947638827875), (86, 0.4969304440873594), (87, 0.3623285086891981), (88, 0.3623285086891981), (89, 0.42962947638827875)]
# [(80, 0.41436889830686086), (90, 0.47927931384653005), (91, 0.22568142181755532), (92, 0.47927931384653005), (93, 0.29705273928843523), (94, 0.47927931384653005)]
# [(95, 0.2825300916080166), (96, 0.475880331102773), (97, 0.3469801714396021), (98, 0.475880331102773), (99, 0.475880331102773), (100, 0.3469801714396021)]
# [(3, 0.06494007459883198), (22, 0.2442506700293865), (93, 0.2751939904214582), (101, 0.44401134700803596), (102, 0.44401134700803596), (103, 0.3487012821643335), (104, 0.38387739128331916), (105, 0.44401134700803596)]
# [(31, 0.14145238720003236), (106, 0.4298988133606813), (107, 0.4298988133606813), (108, 0.4298988133606813), (109, 0.23648736437874004), (110, 0.4298988133606813), (111, 0.4298988133606813)]
# [(31, 0.14460633764786404), (91, 0.20694284566858243), (112, 0.3799633938920304), (113, 0.43948422638735457), (114, 0.2609217289013819), (115, 0.43948422638735457), (116, 0.3799633938920304), (117, 0.43948422638735457)]
# [(3, 0.05576545231754243), (87, 0.2780055186306381), (118, 0.2175925410383166), (119, 0.38128218596887414), (120, 0.38128218596887414), (121, 0.38128218596887414), (122, 0.38128218596887414), (123, 0.38128218596887414), (124, 0.38128218596887414)]
# [(125, 0.316227766016838), (126, 0.316227766016838), (127, 0.316227766016838), (128, 0.316227766016838), (129, 0.316227766016838), (130, 0.316227766016838), (131, 0.316227766016838), (132, 0.316227766016838), (133, 0.316227766016838), (134, 0.316227766016838)]
# [(135, 0.43675092295088713), (136, 0.37760027096770143), (137, 0.37760027096770143), (138, 0.43675092295088713), (139, 0.37760027096770143), (140, 0.43675092295088713)]
# [(3, 0.06448243391037195), (22, 0.24252940553316307), (118, 0.2516055382640441), (141, 0.4408823444655523), (142, 0.4408823444655523), (143, 0.4408823444655523), (144, 0.3811721601187973), (145, 0.3811721601187973)]
# [(30, 0.3425148669713128), (146, 0.4697562042974057), (147, 0.4697562042974057), (148, 0.4697562042974057), (149, 0.4697562042974057)]
# [(3, 0.06132389477496695), (109, 0.2306496024238733), (150, 0.32928389545961895), (151, 0.41928663142160705), (152, 0.36250122740035295), (153, 0.41928663142160705), (154, 0.41928663142160705), (155, 0.41928663142160705)]
# [(31, 0.1359731396483473), (156, 0.4132464113248796), (157, 0.4132464113248796), (158, 0.35727905470334115), (159, 0.4132464113248796), (160, 0.4132464113248796), (161, 0.4132464113248796)]
# [(31, 0.1406536403912511), (162, 0.4274712805910497), (163, 0.369577401901087), (164, 0.33571165384615914), (165, 0.4274712805910497), (166, 0.4274712805910497), (167, 0.4274712805910497)]
# [(22, 0.24390842448133043), (31, 0.1458912149142487), (91, 0.20878160434379348), (95, 0.2632401086019145), (114, 0.2632401086019145), (168, 0.4433891955650876), (169, 0.3232898042563055), (170, 0.30395812013572143), (171, 0.38333949991069655), (172, 0.4433891955650876)]
# [(9, 0.4242289776035836), (24, 0.3781346845042625), (173, 0.581826406643889), (174, 0.581826406643889)]
# [(175, 0.3694672444945854), (176, 0.3694672444945854), (177, 0.3694672444945854), (178, 0.2108499151506772), (179, 0.3694672444945854), (180, 0.3694672444945854), (181, 0.3694672444945854), (182, 0.3694672444945854)]
# [(3, 0.12221001966608487), (31, 0.2749363321484747), (109, 0.45965267782865493), (183, 0.8355801219050784)]
# [(3, 0.07325441708730898), (72, 0.4330255963697669), (184, 0.3433552928249419), (185, 0.5008585623923746), (186, 0.4330255963697669), (187, 0.5008585623923746)]
# [(3, 0.07484220911125512), (22, 0.2814942827649956), (188, 0.5117146890549334), (189, 0.5117146890549334), (190, 0.44241144114771347), (191, 0.44241144114771347)]
# [(31, 0.17406258944284225), (62, 0.32787347375803966), (95, 0.3140713782896131), (192, 0.41545202535857234), (193, 0.41545202535857234), (194, 0.4573617817179698), (195, 0.4573617817179698)]
# [(61, 0.3158014138129688), (196, 0.36527134527349664), (197, 0.36527134527349664), (198, 0.36527134527349664), (199, 0.3158014138129688), (200, 0.36527134527349664), (201, 0.36527134527349664), (202, 0.36527134527349664)]
# [(34, 0.4854027054395339), (62, 0.38307833754486853), (203, 0.6180771913020427), (204, 0.4854027054395339)]
# [(97, 0.36940639956876986), (205, 0.5066377107628738), (206, 0.4380220551658218), (207, 0.5066377107628738), (208, 0.39788446967914864)]
# [(3, 0.059048033260204594), (43, 0.3490480278682294), (44, 0.3490480278682294), (45, 0.3490480278682294), (46, 0.2623854868457647), (48, 0.2943700522170494), (49, 0.3490480278682294), (50, 0.2623854868457647), (209, 0.3490480278682294), (210, 0.4037260035194094)]
# [(71, 0.3205908566876423), (211, 0.40821753574527), (212, 0.40821753574527), (213, 0.40821753574527), (214, 0.40821753574527), (215, 0.253009328204673), (216, 0.40821753574527)]
# [(3, 0.0652689582167587), (217, 0.4462600056230222), (218, 0.4462600056230222), (219, 0.4462600056230222), (220, 0.4462600056230222), (221, 0.4462600056230222)]
# [(91, 0.20144002796107746), (222, 0.3698597863700711), (223, 0.3698597863700711), (224, 0.42779790026518216), (225, 0.42779790026518216), (226, 0.3698597863700711), (227, 0.42779790026518216)]
# [(228, 0.341859343003591), (229, 0.23435601112871643), (230, 0.341859343003591), (231, 0.341859343003591), (232, 0.341859343003591), (233, 0.341859343003591), (234, 0.23435601112871643), (235, 0.341859343003591), (236, 0.341859343003591), (237, 0.26847690273791897)]
# [(3, 0.0652689582167587), (238, 0.4462600056230222), (239, 0.4462600056230222), (240, 0.4462600056230222), (241, 0.4462600056230222), (242, 0.4462600056230222)]
# [(3, 0.05777425914885272), (54, 0.25672535183558065), (229, 0.27079729054638946), (243, 0.3950168949688091), (244, 0.341518423290923), (245, 0.3950168949688091), (246, 0.3950168949688091), (247, 0.3950168949688091), (248, 0.341518423290923)]
# [(249, 0.3053069255592091), (250, 0.38875606773519383), (251, 0.38875606773519383), (252, 0.38875606773519383), (253, 0.38875606773519383), (254, 0.38875606773519383), (255, 0.38875606773519383)]
# [(3, 0.0867570463273105), (178, 0.3385193767611563), (256, 0.5128430915010533), (257, 0.5128430915010533), (258, 0.593179377144118)]
# [(3, 0.074263313589472), (31, 0.16707045058391082), (169, 0.37022224606212467), (170, 0.34808415379611546), (259, 0.5077566372357495), (260, 0.5077566372357495), (261, 0.4389894416489371)]
# [(91, 0.16432079544607112), (222, 0.30170594650427257), (223, 0.30170594650427257), (226, 0.30170594650427257), (262, 0.3489678390797108), (263, 0.3489678390797108), (264, 0.30170594650427257), (265, 0.3489678390797108), (266, 0.3489678390797108), (267, 0.3489678390797108)]
# [(3, 0.07827483870822785), (35, 0.3668868204009617), (268, 0.535184426355773), (269, 0.535184426355773), (270, 0.535184426355773)]
# [(63, 0.2695015588841401), (91, 0.22236729703647248), (109, 0.25977986540915454), (114, 0.28036948755794594), (271, 0.3069141272568221), (272, 0.4082839037010624), (273, 0.4082839037010624), (274, 0.3708713353283803), (275, 0.4082839037010624)]
# [(3, 0.05599253437191553), (152, 0.3309861924060542), (178, 0.21847859789218882), (276, 0.3309861924060542), (277, 0.3309861924060542), (278, 0.3828348021225575), (279, 0.3006567000073731), (280, 0.3828348021225575), (281, 0.3828348021225575), (282, 0.3006567000073731)]
# [(3, 0.08495581649448576), (50, 0.377509157215372), (89, 0.502195561241843), (109, 0.319533280949526), (234, 0.3982016431156583), (283, 0.5808639234079753)]
# [(3, 0.05468577743023364), (215, 0.2317397601295085), (284, 0.32326161788234037), (285, 0.3739001818057106), (286, 0.3739001818057106), (287, 0.3739001818057106), (288, 0.3739001818057106), (289, 0.3739001818057106), (290, 0.3739001818057106)]
# [(16, 0.31837486734961234), (31, 0.16118689337508313), (68, 0.31837486734961234), (91, 0.23067090241055407), (114, 0.2908390018014581), (271, 0.31837486734961234), (291, 0.4235299783806816), (292, 0.3358260134416233), (293, 0.4898754666702934)]
# [(3, 0.06287908913574171), (4, 0.31346887830595055), (88, 0.31346887830595055), (178, 0.24534940925991236), (294, 0.42991987980101876), (295, 0.42991987980101876), (296, 0.42991987980101876), (297, 0.42991987980101876)]
# [(3, 0.09333368124213288), (22, 0.3510438557474365), (93, 0.39551645637020755), (190, 0.551719262649927), (298, 0.6381454561846692)]
# [(109, 0.22610168819080398), (150, 0.3227911250444799), (299, 0.4110192005709192), (300, 0.4110192005709192), (301, 0.4110192005709192), (302, 0.4110192005709192), (303, 0.4110192005709192)]
# [(178, 0.24729186858778016), (304, 0.43332360464908076), (305, 0.43332360464908076), (306, 0.43332360464908076), (307, 0.43332360464908076), (308, 0.43332360464908076)]
# [(16, 0.2790988209759384), (309, 0.4294423938387641), (310, 0.4294423938387641), (311, 0.4294423938387641), (312, 0.4294423938387641), (313, 0.4294423938387641)]
# [(3, 0.0589623807932344), (215, 0.2498625533690342), (314, 0.40314037642444633), (315, 0.40314037642444633), (316, 0.40314037642444633), (317, 0.34854171422783686), (318, 0.40314037642444633), (319, 0.40314037642444633)]
# [(3, 0.07400823578617048), (95, 0.30041962008104706), (100, 0.36895061579551797), (320, 0.5060126072244598), (321, 0.5060126072244598), (322, 0.5060126072244598)]
# [(10, 0.23666775838902854), (87, 0.2784204446814945), (118, 0.21791730010854496), (204, 0.29988427679988305), (323, 0.7637025069824426), (324, 0.3818512534912213)]
# [(3, 0.05935388413783267), (31, 0.13352865213677637), (118, 0.2315943282680434), (249, 0.3187057549309899), (325, 0.40581718159393654), (326, 0.40581718159393654), (327, 0.40581718159393654), (328, 0.40581718159393654), (329, 0.40581718159393654)]
# [(16, 0.2711938313154056), (24, 0.2711938313154056), (54, 0.2711938313154056), (71, 0.3277073598785549), (330, 0.3607656548714313), (331, 0.3607656548714313), (332, 0.3607656548714313), (333, 0.4172791834345806), (334, 0.3277073598785549)]
# [(3, 0.09469283299003203), (335, 0.5084612618537269), (336, 0.5597535562747001), (337, 0.6474383127466768)]
# [(3, 0.07427855291308086), (31, 0.16710473454646066), (276, 0.4390795251886933), (338, 0.5078608322593133), (339, 0.5078608322593133), (340, 0.5078608322593133)]
# [(95, 0.268642068085631), (100, 0.3299240456466714), (341, 0.452488000768752), (342, 0.452488000768752), (343, 0.452488000768752), (344, 0.452488000768752)]
# [(3, 0.057878439885579495), (208, 0.3107832308855381), (345, 0.3957292044253673), (346, 0.3957292044253673), (347, 0.34213426227299537), (348, 0.3957292044253673), (349, 0.3957292044253673), (350, 0.3957292044253673)]
# [(91, 0.19376058889068973), (109, 0.2263601724464276), (114, 0.2443010179113624), (271, 0.26743079053751356), (272, 0.3557597302751405), (273, 0.3557597302751405), (274, 0.32316014671940263), (275, 0.3557597302751405), (351, 0.3557597302751405), (352, 0.41148908645702953)]
# [(3, 0.08481535091297994), (93, 0.35941866422123), (104, 0.5013652332613677), (118, 0.3309430293710047), (353, 0.5013652332613677), (354, 0.5013652332613677)]
# [(31, 0.2265626598915447), (62, 0.4267653753760511), (279, 0.5407590236584191), (355, 0.6885639794928282)]
# [(91, 0.19272987986869533), (186, 0.3538672671805751), (356, 0.4093001711761064), (357, 0.4093001711761064), (358, 0.4093001711761064), (359, 0.4093001711761064), (360, 0.4093001711761064)]
# [(31, 0.1331328103633926), (361, 0.40461414846014), (362, 0.40461414846014), (363, 0.40461414846014), (364, 0.40461414846014), (365, 0.40461414846014), (366, 0.40461414846014)]
# [(97, 0.3425148669713128), (367, 0.4697562042974057), (368, 0.4697562042974057), (369, 0.4697562042974057), (370, 0.4697562042974057)]
# [(3, 0.07948042825984174), (31, 0.17880741270689063), (46, 0.3531787548582645), (67, 0.4267769541748513), (170, 0.37253761348594), (371, 0.5434273402122428), (372, 0.46982914089565603)]
# [(3, 0.07903192215313457), (68, 0.3511857758094437), (335, 0.42436866229293624), (373, 0.4671779065803126), (374, 0.42436866229293624), (375, 0.5403607930638051)]
# [(3, 0.08336559483392698), (31, 0.18754788628330793), (48, 0.4155995238017085), (50, 0.37044285777132935), (91, 0.2683955206797862), (109, 0.3135521867101653), (234, 0.39074801716888496), (376, 0.5699911847191479)]
# [(377, 0.5), (378, 0.5), (379, 0.5), (380, 0.5)]
# [(330, 0.2923190373270414), (381, 0.33811048128093274), (382, 0.33811048128093274), (383, 0.33811048128093274), (384, 0.33811048128093274), (385, 0.33811048128093274), (386, 0.33811048128093274), (387, 0.33811048128093274), (388, 0.33811048128093274)]
# [(3, 0.06573601727675361), (31, 0.14788656060690406), (118, 0.2564969249337178), (389, 0.4494534039004609), (390, 0.4494534039004609), (391, 0.4494534039004609), (392, 0.3885824120382092), (393, 0.3885824120382092)]
# [(3, 0.0589623807932344), (215, 0.2498625533690342), (394, 0.34854171422783686), (395, 0.40314037642444633), (396, 0.40314037642444633), (397, 0.40314037642444633), (398, 0.40314037642444633), (399, 0.40314037642444633)]
# [(3, 0.08296032257019237), (184, 0.38884844056557133), (192, 0.44546254416395575), (400, 0.5672202380450422), (401, 0.5672202380450422)]
# [(3, 0.06697475289597443), (70, 0.39590489512640653), (402, 0.4579229456168014), (403, 0.4579229456168014), (404, 0.4579229456168014), (405, 0.4579229456168014)]
# [(406, 0.4265972899178322), (407, 0.4265972899178322), (408, 0.4265972899178322), (409, 0.4265972899178322), (410, 0.36882177873536953), (411, 0.36882177873536953)]
# [(63, 0.24184862062850263), (354, 0.3663908266199392), (412, 0.42378553192480256), (413, 0.42378553192480256), (414, 0.42378553192480256), (415, 0.3663908266199392), (416, 0.3663908266199392)]
# [(274, 0.3473570899529769), (373, 0.38239760033940245), (417, 0.44229974849971476), (418, 0.44229974849971476), (419, 0.44229974849971476), (420, 0.38239760033940245)]
# [(3, 0.09261462534326645), (31, 0.20835546434536126), (374, 0.49730214823232194), (421, 0.547468739312082), (422, 0.6332290932115429)]
# [(3, 0.06697475289597443), (423, 0.4579229456168014), (424, 0.39590489512640653), (425, 0.4579229456168014), (426, 0.4579229456168014), (427, 0.4579229456168014)]
# [(3, 0.06309335260032418), (88, 0.31453703830679947), (118, 0.24618544895425026), (424, 0.3729609451967999), (428, 0.3729609451967999), (429, 0.4313848520868003), (430, 0.4313848520868003), (431, 0.4313848520868003)]
# [(3, 0.06938134735083405), (46, 0.30830253943331115), (432, 0.47437742695525537), (433, 0.47437742695525537), (434, 0.47437742695525537), (435, 0.47437742695525537)]
# [(95, 0.4562147324866106), (193, 0.30173926647210486), (336, 0.3321779654554466), (436, 0.38421326506151726), (437, 0.38421326506151726), (438, 0.38421326506151726), (439, 0.38421326506151726)]
# [(3, 0.06968183172006566), (215, 0.29528794737889497), (440, 0.47643191288496184), (441, 0.47643191288496184), (442, 0.47643191288496184), (443, 0.47643191288496184)]
# [(3, 0.06288875949396647), (54, 0.27945211492880506), (144, 0.3717515430144291), (229, 0.2947697803084305), (392, 0.3717515430144291), (444, 0.42998599843127827), (445, 0.42998599843127827), (446, 0.42998599843127827)]
# [(447, 0.408248290463863), (448, 0.408248290463863), (449, 0.408248290463863), (450, 0.408248290463863), (451, 0.408248290463863), (452, 0.408248290463863)]
# [(54, 0.26159394343410847), (69, 0.2934820203437078), (164, 0.31610697097055207), (215, 0.2494706592458983), (229, 0.2759327452423581), (453, 0.40250807541659506), (454, 0.34799504788015145), (455, 0.40250807541659506), (456, 0.40250807541659506)]
# [(62, 0.38307833754486853), (334, 0.4854027054395339), (335, 0.4854027054395339), (457, 0.6180771913020427)]
# [(3, 0.06842545396465748), (63, 0.2669909017340922), (91, 0.22029573928165644), (458, 0.4678417475213428), (459, 0.4678417475213428), (460, 0.4678417475213428), (461, 0.4678417475213428)]
# [(3, 0.08123708580468492), (31, 0.1827593716668822), (206, 0.480213192959937), (208, 0.4362094770352652), (462, 0.5554380421945851), (463, 0.480213192959937)]
# [(10, 0.2960074625062519), (464, 0.4775928135296348), (465, 0.4775928135296348), (466, 0.4775928135296348), (467, 0.4775928135296348)]
# [(468, 0.35926912455193216), (469, 0.35926912455193216), (470, 0.3106120941074543), (471, 0.35926912455193216), (472, 0.35926912455193216), (473, 0.35926912455193216), (474, 0.35926912455193216), (475, 0.35926912455193216)]
# [(3, 0.10675084850954734), (31, 0.2401577777595055), (476, 0.6310315702018441), (477, 0.7298819462986483)]
# [(95, 0.2483096150384891), (193, 0.3284626986564201), (478, 0.418240977971514), (479, 0.418240977971514), (480, 0.418240977971514), (481, 0.36159719032717236), (482, 0.418240977971514)]
# [(33, 0.31755753683026805), (39, 0.31755753683026805), (46, 0.238713535818077), (428, 0.31755753683026805), (454, 0.31755753683026805), (483, 0.3673025629594775), (484, 0.3673025629594775), (485, 0.3673025629594775), (486, 0.3673025629594775)]
# [(3, 0.08786110502205279), (16, 0.39041907991125363), (35, 0.4118192000192206), (63, 0.34282732956814627), (88, 0.4380108302543611), (487, 0.6007280994278044)]
# [(24, 0.2790988209759384), (488, 0.4294423938387641), (489, 0.4294423938387641), (490, 0.4294423938387641), (491, 0.4294423938387641), (492, 0.4294423938387641)]
# [(22, 0.29779196192574015), (50, 0.35182310974942305), (229, 0.3711076611271569), (234, 0.3711076611271569), (493, 0.5413414428992375), (494, 0.46802574369782074)]
# [(30, 0.31154006310046356), (47, 0.33555713418944233), (292, 0.2929109754785407), (331, 0.36940729468968164), (334, 0.33555713418944233), (347, 0.36940729468968164), (495, 0.36940729468968164), (496, 0.4272745262788998)]
# [(10, 0.2670073835699999), (24, 0.2799828829780441), (184, 0.29532964145426144), (353, 0.37245761690239243), (497, 0.4308026779888676), (498, 0.37245761690239243), (499, 0.4308026779888676), (500, 0.33832794406451927)]
# [(3, 0.07248409650760614), (109, 0.272625020033099), (163, 0.4284720343910515), (501, 0.4955916901207492), (502, 0.4955916901207492), (503, 0.4955916901207492)]
# [(495, 0.332834095814436), (504, 0.3849721774932544), (505, 0.3849721774932544), (506, 0.3849721774932544), (507, 0.3849721774932544), (508, 0.3849721774932544), (509, 0.3849721774932544)]
# [(91, 0.2113641112647477), (114, 0.26649623552207047), (169, 0.3272887109587899), (170, 0.30771790515796), (171, 0.38808118639550937), (271, 0.29172739250229696), (292, 0.30771790515796), (411, 0.38808118639550937), (510, 0.44887366183222877)]
# [(3, 0.06324993075725638), (31, 0.14229360259133456), (234, 0.2964626483947202), (511, 0.4324554156610027), (512, 0.4324554156610027), (513, 0.3738865187318842), (514, 0.4324554156610027), (515, 0.4324554156610027)]
# [(31, 0.1199023977573355), (50, 0.23683011181350314), (516, 0.36440458542482024), (517, 0.36440458542482024), (518, 0.36440458542482024), (519, 0.36440458542482024), (520, 0.36440458542482024), (521, 0.36440458542482024), (522, 0.36440458542482024)]
# [(31, 0.1390033787418794), (332, 0.365241222537828), (523, 0.422455843673776), (524, 0.365241222537828), (525, 0.422455843673776), (526, 0.422455843673776), (527, 0.422455843673776)]
# [(3, 0.06646686497540388), (137, 0.3929026397206753), (139, 0.3929026397206753), (178, 0.25934863690326804), (528, 0.4544503903243304), (529, 0.4544503903243304), (530, 0.4544503903243304)]
# [(3, 0.08985073774622672), (63, 0.35059072468454894), (109, 0.33794391264135215), (531, 0.61433171031629), (532, 0.61433171031629)]
# [(533, 0.32029777740395327), (534, 0.32029777740395327), (535, 0.32029777740395327), (536, 0.27691876807249594), (537, 0.32029777740395327), (538, 0.32029777740395327), (539, 0.32029777740395327), (540, 0.32029777740395327), (541, 0.32029777740395327), (542, 0.32029777740395327)]
# [(536, 0.3967958325206154), (543, 0.45895344733814547), (544, 0.45895344733814547), (545, 0.45895344733814547), (546, 0.45895344733814547)]
# [(136, 0.3309602702708535), (150, 0.300633153213563), (199, 0.3309602702708535), (209, 0.3309602702708535), (261, 0.3309602702708535), (292, 0.26242550432338546), (351, 0.3309602702708535), (547, 0.38280481931442883), (548, 0.38280481931442883)]
# [(17, 0.4077894539313454), (264, 0.4077894539313454), (549, 0.47166920701014964), (550, 0.47166920701014964), (551, 0.47166920701014964)]
# [(3, 0.07533786735808524), (145, 0.44534140382386705), (552, 0.5151036270441521), (553, 0.5151036270441521), (554, 0.5151036270441521)]
# [(91, 0.2009370995075639), (114, 0.25334944648391977), (271, 0.27733590033594757), (555, 0.4267298318252875), (556, 0.3689363700448316), (557, 0.4267298318252875), (558, 0.4267298318252875), (559, 0.3689363700448316)]
# [(3, 0.10287113151670121), (560, 0.7033553619261296), (561, 0.7033553619261296)]
# [(393, 0.4077894539313454), (394, 0.4077894539313454), (562, 0.47166920701014964), (563, 0.47166920701014964), (564, 0.47166920701014964)]
# [(31, 0.17756083680575518), (178, 0.307964486038684), (565, 0.5396387756551504), (566, 0.5396387756551504), (567, 0.5396387756551504)]
# [(16, 0.2875275617864481), (22, 0.2433705869779103), (93, 0.27420241251991595), (568, 0.44241148707267575), (569, 0.44241148707267575), (570, 0.44241148707267575), (571, 0.44241148707267575)]
# [(22, 0.27334403284449055), (191, 0.42960207330682215), (572, 0.49689874834443215), (573, 0.49689874834443215), (574, 0.49689874834443215)]
# [(3, 0.06756290048950632), (24, 0.30022209985439985), (498, 0.3993815859877786), (575, 0.3993815859877786), (576, 0.3993815859877786), (577, 0.4619442561381836), (578, 0.4619442561381836)]
# [(3, 0.06697475289597443), (420, 0.39590489512640653), (579, 0.4579229456168014), (580, 0.4579229456168014), (581, 0.4579229456168014), (582, 0.4579229456168014)]
# [(3, 0.06620380134563075), (34, 0.355486970964913), (158, 0.3913476033188439), (291, 0.3913476033188439), (481, 0.3913476033188439), (583, 0.45265175924289186), (584, 0.45265175924289186)]
# [(3, 0.06454912357840409), (32, 0.34660203723847205), (103, 0.34660203723847205), (215, 0.2735372727161658), (585, 0.38156637980437463), (586, 0.4413383182154654), (587, 0.4413383182154654), (588, 0.38156637980437463)]
# [(237, 0.3053069255592091), (589, 0.38875606773519383), (590, 0.38875606773519383), (591, 0.38875606773519383), (592, 0.38875606773519383), (593, 0.38875606773519383), (594, 0.38875606773519383)]
# [(595, 0.408248290463863), (596, 0.408248290463863), (597, 0.408248290463863), (598, 0.408248290463863), (599, 0.408248290463863), (600, 0.408248290463863)]
# [(3, 0.06302319709036723), (103, 0.3384084445123476), (524, 0.37254623803311404), (601, 0.4309051815186888), (602, 0.4309051815186888), (603, 0.4309051815186888), (604, 0.4309051815186888)]
# [(10, 0.276995361318627), (69, 0.3258626024854367), (87, 0.3258626024854367), (118, 0.25504987114435934), (500, 0.3509838187144024), (605, 0.4469177662844455), (606, 0.3509838187144024), (607, 0.4469177662844455)]
# [(463, 0.339242714722138), (608, 0.339242714722138), (609, 0.3923846992470293), (610, 0.3923846992470293), (611, 0.3923846992470293), (612, 0.3923846992470293), (613, 0.3923846992470293)]
# [(68, 0.5038803138868843), (184, 0.2657498037973697), (256, 0.3351527402642246), (614, 0.3876540349528502), (615, 0.3351527402642246), (616, 0.3876540349528502), (617, 0.3876540349528502)]
# [(284, 0.3158014138129688), (618, 0.3158014138129688), (619, 0.36527134527349664), (620, 0.36527134527349664), (621, 0.36527134527349664), (622, 0.36527134527349664), (623, 0.36527134527349664), (624, 0.36527134527349664)]
# [(3, 0.06899334823962382), (31, 0.15521459009231067), (237, 0.37046568148537196), (421, 0.407837328517709), (625, 0.47172458109589016), (626, 0.47172458109589016), (627, 0.47172458109589016)]
# [(3, 0.07461714259318351), (63, 0.2911503984477092), (628, 0.5101758536213016), (629, 0.44108101539202604), (630, 0.5101758536213016), (631, 0.44108101539202604)]
# [(3, 0.06374825424917376), (116, 0.3768322363534632), (632, 0.3768322363534632), (633, 0.43586257658988714), (634, 0.43586257658988714), (635, 0.3768322363534632), (636, 0.43586257658988714)]
# [(3, 0.08095725433166451), (19, 0.47855903754780293), (415, 0.47855903754780293), (416, 0.47855903754780293), (637, 0.5535247652228757)]
# [(3, 0.07678593253203927), (244, 0.4539012874522684), (248, 0.4539012874522684), (257, 0.4539012874522684), (374, 0.4123086290169997), (638, 0.4539012874522684)]
# [(615, 0.4624639953037667), (638, 0.4624639953037667), (639, 0.5349084529596422), (640, 0.5349084529596422)]
# [(3, 0.07197169978484311), (31, 0.16191499855250652), (641, 0.4920883070328491), (642, 0.4920883070328491), (643, 0.4920883070328491), (644, 0.4920883070328491)]
# [(22, 0.19386577368340857), (29, 0.2767699423017008), (68, 0.22904063269606717), (93, 0.21842599596415332), (118, 0.20112077639146145), (645, 0.3524191082119403), (646, 0.3524191082119403), (647, 0.3524191082119403), (648, 0.3524191082119403), (649, 0.3524191082119403), (650, 0.3524191082119403)]
# [(3, 0.058700534048120374), (82, 0.34699387114247937), (91, 0.1889863609971514), (184, 0.2751388907108598), (556, 0.34699387114247937), (651, 0.4013500654843071), (652, 0.4013500654843071), (653, 0.4013500654843071), (654, 0.4013500654843071)]
# [(10, 0.24529780893300815), (655, 0.3957753960966299), (656, 0.3957753960966299), (657, 0.3957753960966299), (658, 0.3957753960966299), (659, 0.3957753960966299), (660, 0.3957753960966299)]
# [(3, 0.06854386984935594), (4, 0.3417093073667537), (661, 0.4686513862043427), (662, 0.4686513862043427), (663, 0.4686513862043427), (664, 0.4686513862043427)]
# [(3, 0.07881364055416422), (54, 0.35021582100395643), (665, 0.5388683477996964), (666, 0.5388683477996964), (667, 0.5388683477996964)]
# [(513, 0.34270876622458435), (606, 0.311305090909276), (668, 0.39639370376603883), (669, 0.39639370376603883), (670, 0.39639370376603883), (671, 0.39639370376603883), (672, 0.39639370376603883)]
# [(3, 0.0701487903153299), (178, 0.2737152287147334), (673, 0.4796246242601961), (674, 0.4796246242601961), (675, 0.4796246242601961), (676, 0.4796246242601961)]
# [(3, 0.08414246411207577), (677, 0.5753028320612685), (678, 0.5753028320612685), (679, 0.5753028320612685)]
# [(63, 0.21851694601587723), (575, 0.33104428825419674), (576, 0.33104428825419674), (680, 0.3829019986190824), (681, 0.3829019986190824), (682, 0.3829019986190824), (683, 0.3829019986190824), (684, 0.3829019986190824)]
# [(69, 0.3425148669713128), (685, 0.4697562042974057), (686, 0.4697562042974057), (687, 0.4697562042974057), (688, 0.4697562042974057)]
# [(62, 0.2420982841769882), (68, 0.2538633001890022), (608, 0.3377110729115079), (689, 0.390613127492834), (690, 0.390613127492834), (691, 0.390613127492834), (692, 0.390613127492834), (693, 0.390613127492834)]
# [(3, 0.0652689582167587), (694, 0.4462600056230222), (695, 0.4462600056230222), (696, 0.4462600056230222), (697, 0.4462600056230222), (698, 0.4462600056230222)]
# [(46, 0.3608930375332104), (63, 0.3169004863834295), (410, 0.48009135160889843), (618, 0.48009135160889843), (699, 0.5552971145348053)]
# [(35, 0.27983074709028344), (97, 0.29762793443820146), (700, 0.40819416106185136), (701, 0.40819416106185136), (702, 0.40819416106185136), (703, 0.40819416106185136), (704, 0.40819416106185136)]
# [(3, 0.0826742741530598), (31, 0.18599261959686655), (705, 0.5652644542892468), (706, 0.5652644542892468), (707, 0.5652644542892468)]
# [(3, 0.07197169978484311), (31, 0.16191499855250652), (708, 0.4920883070328491), (709, 0.4920883070328491), (710, 0.4920883070328491), (711, 0.4920883070328491)]
# [(3, 0.06697475289597443), (588, 0.39590489512640653), (712, 0.4579229456168014), (713, 0.4579229456168014), (714, 0.4579229456168014), (715, 0.4579229456168014)]
# [(3, 0.025380525170212193), (31, 0.17129598335798374), (62, 0.10755404954075273), (91, 0.08171259716620241), (93, 0.10755404954075273), (114, 0.10302647601440873), (192, 0.1362828996352325), (194, 0.15003077609518045), (249, 0.1362828996352325), (271, 0.11278074959484663), (277, 0.15003077609518045), (279, 0.1362828996352325), (282, 0.1362828996352325), (494, 0.15003077609518045), (629, 0.15003077609518045), (635, 0.15003077609518045), (716, 0.1735329261355663), (717, 0.1735329261355663), (718, 0.1735329261355663), (719, 0.1735329261355663), (720, 0.1735329261355663), (721, 0.1735329261355663), (722, 0.1735329261355663), (723, 0.1735329261355663), (724, 0.1735329261355663), (725, 0.15003077609518045), (726, 0.1735329261355663), (727, 0.1735329261355663), (728, 0.1735329261355663), (729, 0.15003077609518045), (730, 0.1735329261355663), (731, 0.1735329261355663), (732, 0.1735329261355663), (733, 0.1735329261355663), (734, 0.1735329261355663), (735, 0.1735329261355663), (736, 0.1735329261355663), (737, 0.1735329261355663), (738, 0.1735329261355663), (739, 0.1735329261355663), (740, 0.15003077609518045)]
# [(3, 0.02622634828282998), (9, 0.05229811112901027), (15, 0.028164923829254937), (27, 0.03100613057158887), (31, 0.10620272249375456), (32, 0.028164923829254937), (48, 0.05229811112901027), (67, 0.028164923829254937), (95, 0.021291980557421403), (100, 0.026149055564505135), (112, 0.03100613057158887), (164, 0.028164923829254937), (169, 0.026149055564505135), (170, 0.024585426660749643), (178, 0.08186656831934912), (195, 0.03100613057158887), (204, 0.028164923829254937), (282, 0.028164923829254937), (292, 0.024585426660749643), (317, 0.03100613057158887), (372, 0.03100613057158887), (470, 0.03100613057158887), (476, 0.03100613057158887), (500, 0.028164923829254937), (559, 0.03100613057158887), (585, 0.03100613057158887), (606, 0.028164923829254937), (631, 0.03100613057158887), (632, 0.03100613057158887), (725, 0.03100613057158887), (729, 0.0930183917147666), (740, 0.03100613057158887), (741, 0.035863205578672605), (742, 0.035863205578672605), (743, 0.035863205578672605), (744, 0.035863205578672605), (745, 0.035863205578672605), (746, 0.035863205578672605), (747, 0.035863205578672605), (748, 0.035863205578672605), (749, 0.28690564462938084), (750, 0.035863205578672605), (751, 0.035863205578672605), (752, 0.39449526136539864), (753, 0.07172641115734521), (754, 0.035863205578672605), (755, 0.07172641115734521), (756, 0.035863205578672605), (757, 0.035863205578672605), (758, 0.035863205578672605), (759, 0.035863205578672605), (760, 0.035863205578672605), (761, 0.035863205578672605), (762, 0.035863205578672605), (763, 0.035863205578672605), (764, 0.035863205578672605), (765, 0.035863205578672605), (766, 0.035863205578672605), (767, 0.035863205578672605), (768, 0.035863205578672605), (769, 0.14345282231469042), (770, 0.035863205578672605), (771, 0.035863205578672605), (772, 0.035863205578672605), (773, 0.035863205578672605), (774, 0.035863205578672605), (775, 0.035863205578672605), (776, 0.035863205578672605), (777, 0.035863205578672605), (778, 0.07172641115734521), (779, 0.035863205578672605), (780, 0.035863205578672605), (781, 0.035863205578672605), (782, 0.035863205578672605), (783, 0.07172641115734521), (784, 0.035863205578672605), (785, 0.035863205578672605), (786, 0.035863205578672605), (787, 0.035863205578672605), (788, 0.035863205578672605), (789, 0.035863205578672605), (790, 0.07172641115734521), (791, 0.035863205578672605), (792, 0.035863205578672605), (793, 0.035863205578672605), (794, 0.035863205578672605), (795, 0.035863205578672605), (796, 0.035863205578672605), (797, 0.035863205578672605), (798, 0.035863205578672605), (799, 0.035863205578672605), (800, 0.035863205578672605), (801, 0.035863205578672605), (802, 0.035863205578672605), (803, 0.035863205578672605), (804, 0.035863205578672605), (805, 0.2151792334720356), (806, 0.035863205578672605), (807, 0.035863205578672605), (808, 0.28690564462938084), (809, 0.035863205578672605), (810, 0.2151792334720356), (811, 0.035863205578672605), (812, 0.035863205578672605), (813, 0.07172641115734521), (814, 0.035863205578672605), (815, 0.035863205578672605), (816, 0.035863205578672605), (817, 0.035863205578672605), (818, 0.035863205578672605), (819, 0.2151792334720356), (820, 0.035863205578672605), (821, 0.035863205578672605), (822, 0.07172641115734521), (823, 0.035863205578672605), (824, 0.035863205578672605), (825, 0.035863205578672605), (826, 0.035863205578672605), (827, 0.035863205578672605), (828, 0.1075896167360178), (829, 0.035863205578672605), (830, 0.035863205578672605), (831, 0.035863205578672605), (832, 0.035863205578672605), (833, 0.035863205578672605), (834, 0.035863205578672605), (835, 0.07172641115734521), (836, 0.035863205578672605), (837, 0.035863205578672605), (838, 0.1075896167360178), (839, 0.035863205578672605), (840, 0.035863205578672605), (841, 0.035863205578672605), (842, 0.035863205578672605), (843, 0.035863205578672605), (844, 0.035863205578672605), (845, 0.035863205578672605), (846, 0.035863205578672605), (847, 0.035863205578672605), (848, 0.0358632055786 ...
# [(885, 1.0)]

# %%
lsi_model = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=10) # initialize an LSI transformation

# %%
corpus_lsi = lsi_model[corpus_tfidf]  # create a double wrapper over the original corpus:

# %%
lsi_model.num_terms
# Out:
# 886

# %%
lsi_model.show_topics()
# Out:
# [(0,
#   '0.311*"disease" + 0.304*"patients" + 0.294*"management" + 0.273*"coronavirus" + 0.234*"2019" + 0.188*"covid-19" + 0.180*"surgical" + 0.163*"patient" + 0.154*"pandemic" + 0.141*"ill"'),
#  (1,
#   '-0.275*"coronavirus" + 0.268*"surgical" + -0.253*"2019" + -0.224*"disease" + 0.196*"covid-19" + 0.182*"pandemic" + 0.179*"outcome" + -0.168*"situation" + -0.168*"traumatic" + -0.168*"fracture"'),
#  (2,
#   '-0.285*"surgical" + -0.242*"management" + -0.216*"outcome" + 0.202*"report" + 0.189*"case" + 0.177*"a" + -0.175*"pandemic" + 0.172*"covid-19." + -0.168*"hematoma" + -0.168*"affects"'),
#  (3,
#   '0.294*"patients" + -0.292*"case" + -0.260*"report" + 0.250*"covid-19." + 0.234*"care" + -0.170*"pneumonia:" + 0.164*"intensive" + -0.155*"a" + -0.145*"patients:" + -0.132*"prednisone/rituximab:"'),
#  (4,
#   '-0.293*"case" + 0.285*"patient" + 0.243*"pneumonia" + 0.232*"pulmonary" + -0.190*"care" + -0.157*"report" + -0.150*"pneumonia:" + 0.145*"acute" + -0.144*"ill" + 0.140*"embolism"'),
#  (5,
#   '-0.298*"management" + 0.263*"infection" + -0.249*"patients" + 0.180*"affects" + 0.180*"hematoma" + 0.180*"chronic" + 0.180*"subdural" + -0.166*"diabetes" + 0.153*"acute" + 0.150*"letter:"'),
#  (6,
#   '0.307*"care" + -0.247*"liver" + 0.193*"patient" + 0.179*"pneumonia" + 0.170*"primary" + 0.168*"intensive" + -0.161*"covid-19:" + 0.151*"management" + -0.140*"outcomes" + -0.126*"syndrome"'),
#  (7,
#   '-0.271*"with" + -0.258*"early" + -0.253*"hydroxychloroquine" + 0.208*"covid-19:" + 0.167*"perspective" + 0.157*"a" + 0.155*"care" + -0.154*"adults" + -0.152*"covid-19." + -0.144*"nonhospitalized"'),
#  (8,
#   '0.212*"syndrome" + 0.206*"care" + 0.197*"respiratory" + 0.184*"during" + -0.154*"patients" + 0.147*"an" + 0.141*"covid-19:" + -0.139*"the" + -0.137*"infection" + 0.129*"pandemic"'),
#  (9,
#   '-0.256*"respiratory" + 0.235*"covid-19." + -0.200*"during" + -0.163*"ventilation" + -0.163*"mechanical" + -0.154*"acute" + 0.146*"management" + 0.140*"covid-19:" + -0.136*"pneumonia" + -0.131*"intubation"')]

# %%
lsi_model.print_topic(0,topn=40)
# Out:
# '0.313*"disease" + 0.302*"patients" + 0.299*"management" + 0.271*"coronavirus" + 0.231*"2019" + 0.188*"covid-19" + 0.182*"surgical" + 0.161*"patient" + 0.157*"pandemic" + 0.141*"ill" + 0.139*"situation" + 0.139*"fracture" + 0.139*"traumatic" + 0.136*"spinal" + 0.127*"case" + 0.120*"critically" + 0.119*"outcome" + 0.117*"outcomes" + 0.109*"with" + 0.108*"pregnant" + 0.101*"acute" + 0.095*"diabetes" + 0.095*"infection" + 0.094*"thyroid" + 0.091*"covid-19." + 0.088*"report" + 0.087*"care" + 0.075*"pancreatitis" + 0.075*"response" + 0.074*"clinical" + 0.071*"to:" + 0.069*"vascular" + 0.064*"a" + 0.063*"urgencies" + 0.063*"perinatal" + 0.062*"2019:" + 0.062*"series" + 0.060*"women" + 0.057*"subdural" + 0.057*"affects"'

# %%
term_df = pd.DataFrame([i.replace('"','').split('*') for i in lsi_model.print_topic(3,topn=10).split('+')]).rename(columns={0:'weight',1:'term'}).set_index('term')
term_df['weight'] = term_df['weight'].astype(float)

term_df.plot.barh()
plt.show()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
plt.close()

# %%
fig, axs = plt.subplots(lsi_model.num_topics,figsize=(20,30))
fig.suptitle('Term Weights per Topic')
for topic_num in range(lsi_model.num_topics):
    term_df = pd.DataFrame([i.replace('"','').split('*') for i in lsi_model.print_topic(topic_num,topn=10).split('+')]).rename(columns={0:'weight',1:'term'}).set_index('term')
    term_df['weight'] = term_df['weight'].astype(float)

    #axs[topic_num] = term_df.plot.barh(title='TOPIC {}'.format(topic_num))
    term_df.sort_values('weight').plot.barh(title='TOPIC {}'.format(topic_num),ax=axs[topic_num])
  
plt.show()
plt.close()

# %%
x=1
y= -2

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(x, y)
axs[1].plot(x, -y)
plt.show()
plt.close()

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0, 0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0, 1]')
axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1, 0]')
axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1, 1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
plt.show()
plt.close()
