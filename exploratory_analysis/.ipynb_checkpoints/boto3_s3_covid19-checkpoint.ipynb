# %%
import sys
# !{sys.executable} -m pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.17.54-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 26.9 MB/s eta 0:00:01
# Collecting botocore<1.21.0,>=1.20.54
#   Downloading botocore-1.20.54-py2.py3-none-any.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 67.1 MB/s eta 0:00:01
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/hadoop/miniconda/lib/python3.7/site-packages (from boto3) (0.10.0)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading s3transfer-0.4.0-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 15.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/hadoop/miniconda/lib/python3.7/site-packages (from botocore<1.21.0,>=1.20.54->boto3) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/hadoop/miniconda/lib/python3.7/site-packages (from botocore<1.21.0,>=1.20.54->boto3) (1.26.4)
# Requirement already satisfied: six>=1.5 in /home/hadoop/miniconda/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.54->boto3) (1.15.0)
# Installing collected packages: botocore, s3transfer, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.20.50
#     Uninstalling botocore-1.20.50:
#       Successfully uninstalled botocore-1.20.50
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 1.2.2 requires botocore<1.19.53,>=1.19.52, but you have botocore 1.20.54 which is incompatible.
# Successfully installed boto3-1.17.54 botocore-1.20.54 s3transfer-0.4.0

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
from pyspark import SparkContext

import time 
from time import sleep

sc = SparkContext()
sc
# Out:
# <SparkContext master=yarn appName=pyspark-shell>

# %%
spark = SparkSession \
 .builder \
 .appName("Python Spark SQL basic example") \
 .config("spark.some.config.option", "some-value") \
 .getOrCreate()

# %%
data = spark.read.csv('s3://bigdatateaching/misc/gosales_tx_naivebayes.csv/',header = True)

# %%
import boto3

# %%
s3r = boto3.resource('s3')
bucket = s3r.Bucket('ai2-semanticscholar-cord-19')
#files_in_bucket = list(bucket.objects.all())

# %%
s3client = boto3.client('s3')
objects = s3client.list_objects(Bucket='ai2-semanticscholar-cord-19')
len(objects['Contents'])
# Out:
# 1000

# %%
json_first_page = [i for i in objects['Contents'] if 'all_sources_metadata' in i['Key']]

# %%
json_first_page
# Out:
# [{'Key': '2020-03-13/all_sources_metadata_2020-03-13.csv',
#   'LastModified': datetime.datetime(2020, 3, 16, 17, 30, 8, tzinfo=tzlocal()),
#   'ETag': '"b92434d9622a104ed6b2727c8fc727d4-6"',
#   'Size': 49839979,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-03-13/all_sources_metadata_2020-03-13.readme',
#   'LastModified': datetime.datetime(2020, 4, 6, 18, 34, 54, tzinfo=tzlocal()),
#   'ETag': '"d31945c945f079e216224c0abe94ad3f"',
#   'Size': 1055,
#   'StorageClass': 'STANDARD'}]

# %%
from tqdm import tqdm
import pandas as pd 
import io 
import boto3

# %%
s3 = boto3.client('s3')

paginator = s3.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket='ai2-semanticscholar-cord-19')
   
metadata = []
for page in tqdm(pages):
    for obj in page['Contents']:
        if 'cord_19_embeddings' in obj['Key']:
            metadata.append(obj)
            print(len(metadata))
        #print(obj['Size'])
# Out:
# 1it [00:01,  1.07s/it]
# 1
# 2
# 3
# 4
# 5
# 6
# 34it [00:10,  3.16it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bd6fa026a291> in <module>
#       5
#       6 metadata = []
# ----> 7 for page in tqdm(pages):
#       8     for obj in page['Contents']:
#       9         if 'cord_19_embeddings' in obj['Key']:
#
# ~/miniconda/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# ~/miniconda/lib/python3.7/site-packages/botocore/paginate.py in __iter__(self)
#     253         self._inject_starting_params(current_kwargs)
#     254         while True:
# --> 255             response = self._make_request(current_kwargs)
#     256             parsed = self._extract_parsed_response(response)
#     257             if first_request:
#
# ~/miniconda/lib/python3.7/site-packages/botocore/paginate.py in _make_request(self, current_kwargs)
#     330
#     331     def _make_request(self, current_kwargs):
# --> 332         return self._method(**current_kwargs)
#     333
#     334     def _extract_parsed_response(self, response):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     661         else:
#     662             http, parsed_response = self._make_request(
# --> 663                 operation_model, request_dict, request_context)
#     664
#     665         self.meta.events.emit(
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     680     def _make_request(self, operation_model, request_dict, request_context):
#     681         try:
# --> 682             return self._endpoint.make_request(operation_model, request_dict)
#     683         except Exception as e:
#     684             self.meta.events.emit(
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
# --> 135             request, operation_model, context)
#     136         while self._needs_retry(attempts, operation_model, request_dict,
#     137                                 success_response, exception):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     165         # If no exception occurs then exception is None.
#     166         success_response, exception = self._do_get_response(
# --> 167             request, operation_model)
#     168         kwargs_to_emit = {
#     169             'response_dict': None,
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model)
#     198             http_response = first_non_none_response(responses)
#     199             if http_response is None:
# --> 200                 http_response = self._send(request)
#     201         except HTTPClientError as e:
#     202             return (None, e)
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in _send(self, request)
#     267
#     268     def _send(self, request):
# --> 269         return self.http_session.send(request)
#     270
#     271
#
# ~/miniconda/lib/python3.7/site-packages/botocore/httpsession.py in send(self, request)
#     321                 preload_content=False,
#     322                 decode_content=False,
# --> 323                 chunked=self._chunked(request.headers),
#     324             )
#     325
#
# ~/miniconda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/miniconda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/miniconda/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/miniconda/lib/python3.7/http/client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# ~/miniconda/lib/python3.7/http/client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# ~/miniconda/lib/python3.7/http/client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# ~/miniconda/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/miniconda/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniconda/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
metadata
# Out:
# [{'Key': '2020-03-13/all_sources_metadata_2020-03-13.csv',
#   'LastModified': datetime.datetime(2020, 3, 16, 17, 30, 8, tzinfo=tzlocal()),
#   'ETag': '"b92434d9622a104ed6b2727c8fc727d4-6"',
#   'Size': 49839979,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-03-13/all_sources_metadata_2020-03-13.readme',
#   'LastModified': datetime.datetime(2020, 4, 6, 18, 34, 54, tzinfo=tzlocal()),
#   'ETag': '"d31945c945f079e216224c0abe94ad3f"',
#   'Size': 1055,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-03-20/metadata.csv',
#   'LastModified': datetime.datetime(2020, 3, 20, 22, 20, 5, tzinfo=tzlocal()),
#   'ETag': '"dfc12f579a5b00c3ecf21aac9d7e257d-8"',
#   'Size': 62763644,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-03-27/metadata.csv',
#   'LastModified': datetime.datetime(2020, 3, 27, 22, 44, 50, tzinfo=tzlocal()),
#   'ETag': '"2e26c53283d9c88e263c2e0bdfb32b59-9"',
#   'Size': 69689204,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-03-27/metadata_with_mag_mapping.csv',
#   'LastModified': datetime.datetime(2020, 3, 30, 19, 42, 11, tzinfo=tzlocal()),
#   'ETag': '"f6a64855f515884d1d0a6d5a8281d1a8-5"',
#   'Size': 70853336,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-04-03/metadata.csv',
#   'LastModified': datetime.datetime(2020, 4, 3, 21, 54, 58, tzinfo=tzlocal()),
#   'ETag': '"b2c9637a0af9b6bce817377f748bc1e1-9"',
#   'Size': 71941935,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-04-03/metadata_with_mag_mapping_04_03.csv',
#   'LastModified': datetime.datetime(2020, 4, 6, 18, 20, 53, tzinfo=tzlocal()),
#   'ETag': '"51dec9fde78436929d300b3abe399a5f-5"',
#   'Size': 72501040,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-04-10/metadata.csv',
#   'LastModified': datetime.datetime(2020, 4, 10, 20, 54, 29, tzinfo=tzlocal()),
#   'ETag': '"49785bac519409ce94512cde80c6d1cf-10"',
#   'Size': 77323567,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-04-17/metadata.csv',
#   'LastModified': datetime.datetime(2020, 4, 17, 15, 51, 55, tzinfo=tzlocal()),
#   'ETag': '"222f1059ca9df9736bc7da88c321d6f4-10"',
#   'Size': 78951834,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-04-24/metadata.csv',
#   'LastModified': datetime.datetime(2020, 4, 24, 21, 53, 38, tzinfo=tzlocal()),
#   'ETag': '"201cd149a41e1aab35efc11ea7f692d3-11"',
#   'Size': 85832277,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-01/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 2, 1, 39, 12, tzinfo=tzlocal()),
#   'ETag': '"b5c18961d84bf79a6005924226ad3217-11"',
#   'Size': 89290114,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-12/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 13, 0, 31, 6, tzinfo=tzlocal()),
#   'ETag': '"35f3b793c93bc4e563171c12b6ca34f7-12"',
#   'Size': 96543381,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-19/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 20, 1, 44, 16, tzinfo=tzlocal()),
#   'ETag': '"5c83be0f7522671bc676fec37a81b277-23"',
#   'Size': 189687667,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-26/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 26, 23, 32, 28, tzinfo=tzlocal()),
#   'ETag': '"b7645140ef6b4f55eeb50b46c04d2c19-25"',
#   'Size': 203803031,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-27/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 27, 20, 48, 49, tzinfo=tzlocal()),
#   'ETag': '"8d64b904550582324fec9c0e0e604b57-25"',
#   'Size': 206327395,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-28/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 29, 2, 6, 43, tzinfo=tzlocal()),
#   'ETag': '"2d60e7229f665e6a395b92358a47ddf9-25"',
#   'Size': 208166667,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-29/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 29, 23, 32, 21, tzinfo=tzlocal()),
#   'ETag': '"17dca22d27acb149f331bb4068746d5e-26"',
#   'Size': 209957902,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-30/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 30, 22, 38, 48, tzinfo=tzlocal()),
#   'ETag': '"99e84b0c5b5bb2606d6febbca901346b-26"',
#   'Size': 210286226,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-05-31/metadata.csv',
#   'LastModified': datetime.datetime(2020, 5, 31, 22, 35, 48, tzinfo=tzlocal()),
#   'ETag': '"b14aebbeb0a80f6e54a384cbef1ef081-26"',
#   'Size': 211157469,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-01/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 1, 20, 36, 38, tzinfo=tzlocal()),
#   'ETag': '"8dc6f6f94cee51cb867383e405e02818-26"',
#   'Size': 212064844,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-02/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 2, 22, 41, 48, tzinfo=tzlocal()),
#   'ETag': '"a3ed0a576a80f9df7be13f5125ed6a36-26"',
#   'Size': 212681087,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-03/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 3, 22, 41, 7, tzinfo=tzlocal()),
#   'ETag': '"0f050f24a93259ca48ac545478bd502c-25"',
#   'Size': 204080315,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-04/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 5, 0, 24, 12, tzinfo=tzlocal()),
#   'ETag': '"fcc0ef73882c78a14de2cce8e356f3c5-25"',
#   'Size': 205363042,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-05/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 5, 22, 48, 7, tzinfo=tzlocal()),
#   'ETag': '"7ed98cf9d7dc936b0f98c334d0116476-25"',
#   'Size': 205753402,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-06/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 6, 22, 43, 41, tzinfo=tzlocal()),
#   'ETag': '"8f7254cf6754dbac9e9b93672073b09b-25"',
#   'Size': 205939231,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-07/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 7, 22, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"e8dcdb33eaf68052633d0ea6ffa88cd9-25"',
#   'Size': 206335138,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-08/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 8, 23, 18, 44, tzinfo=tzlocal()),
#   'ETag': '"a5ff25d1bbd917da424a16c887d38c27-25"',
#   'Size': 207226069,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-09/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 9, 23, 29, 8, tzinfo=tzlocal()),
#   'ETag': '"99ce390e77bb62816ffac8fbecc7d0cd-25"',
#   'Size': 209245657,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-10/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 10, 23, 28, 23, tzinfo=tzlocal()),
#   'ETag': '"d3f56b7525cbee89b597592b3c5d1883-26"',
#   'Size': 210469961,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-11/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 11, 23, 30, 15, tzinfo=tzlocal()),
#   'ETag': '"42bc2bd786dcc56bbba7a2ea3fd483a6-26"',
#   'Size': 211687469,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-12/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 13, 6, 27, 44, tzinfo=tzlocal()),
#   'ETag': '"6716d5e992987ff382fac70b18163f98-26"',
#   'Size': 211977384,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-13/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 14, 2, 41, 33, tzinfo=tzlocal()),
#   'ETag': '"b4ca24d2bfd8791b5fad8751b27c4ccf-26"',
#   'Size': 213145018,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-14/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 15, 1, 4, 36, tzinfo=tzlocal()),
#   'ETag': '"93766fa8707de7cb8efbfba5504d11ac-26"',
#   'Size': 214616510,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-15/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 15, 23, 28, 30, tzinfo=tzlocal()),
#   'ETag': '"8d682828dba788939098731ffeacd5a4-26"',
#   'Size': 215205049,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-16/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 16, 23, 36, 17, tzinfo=tzlocal()),
#   'ETag': '"8ce83bb6368b2a1b50242f2650dd5514-27"',
#   'Size': 218699258,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-17/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 18, 1, 27, 58, tzinfo=tzlocal()),
#   'ETag': '"80487ae653b46cd978341bf02a87ee1d-28"',
#   'Size': 227429008,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-18/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 18, 23, 34, 10, tzinfo=tzlocal()),
#   'ETag': '"2d227ddc730973c5896c9f266564e7b0-28"',
#   'Size': 227921096,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-19/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 19, 23, 40, 3, tzinfo=tzlocal()),
#   'ETag': '"53ec0ee66dc2f4e147e8479b50664e52-28"',
#   'Size': 228730850,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-20/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 20, 23, 54, 24, tzinfo=tzlocal()),
#   'ETag': '"a92e9f8075b008bedd3660a4171c7e04-28"',
#   'Size': 229332793,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-21/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 21, 23, 36, 13, tzinfo=tzlocal()),
#   'ETag': '"cd3a89cdd03febd592bf6f5e9973e9ba-28"',
#   'Size': 229465688,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-22/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 22, 23, 38, 57, tzinfo=tzlocal()),
#   'ETag': '"320853c438bff0e6ccde64b90e3a0d19-28"',
#   'Size': 229613973,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-23/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 24, 0, 55, 16, tzinfo=tzlocal()),
#   'ETag': '"4cc0c21dd8e6a72e353d186345510182-28"',
#   'Size': 231506982,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-24/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 24, 22, 58, 43, tzinfo=tzlocal()),
#   'ETag': '"8844b5bd4009b3369b1638b53e3f2c8a-28"',
#   'Size': 230963737,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-25/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 25, 23, 45, 32, tzinfo=tzlocal()),
#   'ETag': '"6b89292665ffa6f91256640a14f70df6-28"',
#   'Size': 233109296,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-26/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 26, 23, 35, 23, tzinfo=tzlocal()),
#   'ETag': '"a8f6214180a7290d021aab6ff7cc447b-29"',
#   'Size': 235757676,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-27/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 27, 23, 43, 46, tzinfo=tzlocal()),
#   'ETag': '"31e61eea35c1acf46b1a607a135d10fe-29"',
#   'Size': 236197085,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-28/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 28, 23, 38, 16, tzinfo=tzlocal()),
#   'ETag': '"b4c74fa7fbd45d927b2217e0115072f4-29"',
#   'Size': 240158754,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-29/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 29, 23, 48, 17, tzinfo=tzlocal()),
#   'ETag': '"402a0bc77c9e11c8ee260d60e97786ff-29"',
#   'Size': 240648707,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-06-30/metadata.csv',
#   'LastModified': datetime.datetime(2020, 6, 30, 23, 47, 47, tzinfo=tzlocal()),
#   'ETag': '"6d6c0851fb05a62fb0bd29a06eb9722a-29"',
#   'Size': 241692246,
#   'StorageClass': 'STANDARD'},
#  {'Key': '2020-07-01/metadata.csv',
#   'LastModified': datetime.datetime(2020, 7, 1, 23, 53, 24, tzinfo=tzlocal()),
#   'ETag': '"07f8d6302b425baba0092d927fe14f1f-29"',
#   'Size': 242867644,
#   'StorageClass': 'STANDARD'}]

# %%
obj = s3.get_object(Bucket='ai2-semanticscholar-cord-19', Key=metadata[0]['Key'])

initial_df = pd.read_csv(io.BytesIO(obj['Body'].read()))

# %%
initial_df['publish_time'].value_counts()
# Out:
# 2020           1148
# 2004 Feb         50
# 2020-03-06       49
# 2020 Jan 21      37
# 2018 Nov 8       36
#                ...
# 2007 Mar 25       1
# 2010 May 20       1
# 2019 Nov 30       1
# 2019-05-03        1
# 2012 Dec 30       1
# Name: publish_time, Length: 4506, dtype: int64

# %%
initial_df.loc[initial_df['publish_time'].str.contains('2020',na=False)].head()
# Out:
#                                         sha source_x  \
# 0  c630ebcdf30652f0422c3ec12a00b50241dc9bd9      CZI
# 1  53eccda7977a31e3d0f565c884da036b1e85438e      CZI
# 2  210a892deb1c61577f6fba58505fd65356ce6636      CZI
# 3  e3b40cc8e0e137c416b4a2273a4dca94ae8178cc      CZI
# 4  92c2c9839304b4f2bc1276d41b1aa885d8b364fd      CZI
#
#                                                title  \
# 0  Angiotensin-converting enzyme 2 (ACE2) as a SA...
# 1  Comparative genetic analysis of the novel coro...
# 2  Incubation Period and Other Epidemiological Ch...
# 3  Characteristics of and Public Health Responses...
# 4       Imaging changes in severe COVID-19 pneumonia
#
#                           doi pmcid   pubmed_id   license  \
# 0  10.1007/s00134-020-05985-9   NaN  32125455.0  cc-by-nc
# 1   10.1038/s41421-020-0147-1   NaN         NaN     cc-by
# 2          10.3390/jcm9020538   NaN         NaN     cc-by
# 3          10.3390/jcm9020575   NaN  32093211.0     cc-by
# 4  10.1007/s00134-020-05976-w   NaN  32125453.0  cc-by-nc
#
#                                             abstract publish_time  \
# 0                                                NaN         2020
# 1                                                NaN         2020
# 2  The geographic spread of 2019 novel coronaviru...         2020
# 3  In December 2019, cases of unidentified pneumo...         2020
# 4                                                NaN         2020
#
#                                              authors  \
# 0  Zhang, Haibo; Penninger, Josef M.; Li, Yimin; ...
# 1  Cao, Yanan; Li, Lin; Feng, Zhimin; Wan, Shengq...
# 2  Linton, M. Natalie; Kobayashi, Tetsuro; Yang, ...
# 3                   Deng, Sheng-Qun; Peng, Hong-Juan
# 4                                         Zhang, Wei
#
#                         journal  Microsoft Academic Paper ID WHO #Covidence  \
# 0            Intensive Care Med                 2.002765e+09          #3252
# 1                Cell Discovery                 3.003431e+09          #1861
# 2  Journal of Clinical Medicine                 3.006065e+09          #1043
# 3                    J Clin Med                 1.776631e+08          #1999
# 4            Intensive Care Med                 3.006643e+09          #3242
#
#   has_full_text
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False

# %%
obj = s3.get_object(Bucket='ai2-semanticscholar-cord-19', Key='2021-04-19/metadata.csv')

initial_df = pd.read_csv(io.BytesIO(obj['Body'].read()))
# Out:
# /home/hadoop/miniconda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
initial_df
# Out:
#         cord_uid                                       sha  \
# 0       ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb
# 1       02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d
# 2       ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927
# 3       2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605
# 4       9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32
# ...          ...                                       ...
# 536812  s2ni25ya  67f15e4baddfc99981e7f13922c75624bbce87a2
# 536813  ohyrqs9v  27da326aad69136482c163f4ed91462e5bae61bd
# 536814  lx06jm0f  d341a5439826720d354c413b5d977702bb1c6102
# 536815  3ky3btb0  b62309980a24a48d107b9dfcac400ac7ffe58d64
# 536816  sb55ybtb  1cff4f38e4614ab793a89acb897ed57f3b85e5cd
#
#                       source_x  \
# 0                          PMC
# 1                          PMC
# 2                          PMC
# 3                          PMC
# 4                          PMC
# ...                        ...
# 536812            Medline; PMC
# 536813           Elsevier; PMC
# 536814            Medline; PMC
# 536815            Medline; PMC
# 536816  Elsevier; Medline; PMC
#
#                                                     title  \
# 0       Clinical features of culture-proven Mycoplasma...
# 1       Nitric oxide: a pro-inflammatory mediator in l...
# 2         Surfactant protein-D and pulmonary host defense
# 3                    Role of endothelin-1 in lung disease
# 4       Gene expression in epithelial cells in respons...
# ...                                                   ...
# 536812  Simulation-based training and assessment of mo...
# 536813  Assessment of the risk of infectious aerosols ...
# 536814  Proteinase‐activated receptor 1 (PAR1): A targ...
# 536815  Making policy decisions under plural uncertain...
# 536816  Evaluation of protection conferred by a vaccin...
#
#                                  doi       pmcid   pubmed_id    license  \
# 0              10.1186/1471-2334-1-6    PMC35282    11472636      no-cc
# 1                       10.1186/rr14    PMC59543    11667967      no-cc
# 2                       10.1186/rr19    PMC59549    11667972      no-cc
# 3                       10.1186/rr44    PMC59574    11686871      no-cc
# 4                       10.1186/rr61    PMC59580    11686888      no-cc
# ...                              ...         ...         ...        ...
# 536812   10.1097/md.0000000000021081  PMC7373634  32702851.0   cc-by-nc
# 536813  10.1016/j.partic.2012.11.009  PMC7148691         NaN  els-covid
# 536814             10.1111/bph.15194  PMC7361899  32639031.0      no-cc
# 536815    10.1007/s40656-021-00411-9  PMC8045439  33852123.0      no-cc
# 536816       10.3382/japr.2013-00828  PMC7109893  32288459.0      no-cc
#
#                                                  abstract publish_time  \
# 0       OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1       Inflammatory diseases of the respiratory tract...   2000-08-15
# 2       Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3       Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4       Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
# ...                                                   ...          ...
# 536812  The World Health Organization has declared cor...   2020-07-17
# 536813  Abstract To assess the risk of infectious bact...   2014-04-30
# 536814  In the search to rapidly identify effective th...   2020-07-08
# 536815  In this paper, I contend that the uncertainty ...   2021-04-14
# 536816  Due to serotype variations among different avi...   2014-06-01
#
#                                                   authors  \
# 0                     Madani, Tariq A; Al-Ghamdi, Aisha A
# 1       Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                         Crouch, Erika C
# 3       Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4       Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# ...                                                   ...
# 536812  Mileder, Lukas P.; Schüttengruber, Gerhilde; P...
# 536813  Wen, Zhanbo; Yang, Wenhui; Li, Na; Wang, Jie; ...
# 536814                    Sriram, Krishna; Insel, Paul A.
# 536815                                    Ongaro, Malvina
# 536816  Bourogâa, Hager; Larbi, Imen; Miled, Khaled; H...
#
#                      journal  mag_id who_covidence_id arxiv_id  \
# 0             BMC Infect Dis     NaN              NaN      NaN
# 1                 Respir Res     NaN              NaN      NaN
# 2                 Respir Res     NaN              NaN      NaN
# 3                 Respir Res     NaN              NaN      NaN
# 4                 Respir Res     NaN              NaN      NaN
# ...                      ...     ...              ...      ...
# 536812  Medicine (Baltimore)     NaN              NaN      NaN
# 536813          Particuology     NaN              NaN      NaN
# 536814        Br J Pharmacol     NaN              NaN      NaN
# 536815  Hist Philos Life Sci     NaN              NaN      NaN
# 536816      J Appl Poult Res     NaN              NaN      NaN
#
#                                            pdf_json_files  \
# 0       document_parses/pdf_json/d1aafb70c066a2068b027...
# 1       document_parses/pdf_json/6b0567729c2143a66d737...
# 2       document_parses/pdf_json/06ced00a5fc04215949aa...
# 3       document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4       document_parses/pdf_json/5f48792a5fa08bed9f560...
# ...                                                   ...
# 536812  document_parses/pdf_json/67f15e4baddfc99981e7f...
# 536813  document_parses/pdf_json/27da326aad69136482c16...
# 536814  document_parses/pdf_json/d341a5439826720d354c4...
# 536815  document_parses/pdf_json/b62309980a24a48d107b9...
# 536816  document_parses/pdf_json/1cff4f38e4614ab793a89...
#
#                                       pmc_json_files  \
# 0         document_parses/pmc_json/PMC35282.xml.json
# 1         document_parses/pmc_json/PMC59543.xml.json
# 2         document_parses/pmc_json/PMC59549.xml.json
# 3         document_parses/pmc_json/PMC59574.xml.json
# 4         document_parses/pmc_json/PMC59580.xml.json
# ...                                              ...
# 536812  document_parses/pmc_json/PMC7373634.xml.json
# 536813                                           NaN
# 536814                                           NaN
# 536815  document_parses/pmc_json/PMC8045439.xml.json
# 536816  document_parses/pmc_json/PMC7109893.xml.json
#
#                                                       url        s2_id
# 0       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# 1       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 2       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 3       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 4       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# ...                                                   ...          ...
# 536812  https://doi.org/10.1097/md.0000000000021081; h...  220731551.0
# 536813  https://www.sciencedirect.com/science/article/...   98632311.0
# 536814  https://doi.org/10.1111/bph.15194; https://www...  220405396.0
# 536815  https://doi.org/10.1007/s40656-021-00411-9; ht...  233234540.0
# 536816  https://doi.org/10.3382/japr.2013-00828; https...   86662553.0
#
# [536817 rows x 19 columns]

# %%
initial_df['publish_time'].value_counts()
# Out:
# 2020           631
# 2006-12-31     394
# 2016-12-31     322
# 2008-12-31     295
# 2017-12-31     275
#               ...
# 2002-09-15       1
# 2005 May 16      1
# 2010 Jan 21      1
# 2009 Jun 1       1
# 2003 Nov 20      1
# Name: publish_time, Length: 7045, dtype: int64

# %%
s3 = boto3.resource('s3')
copy_source = {
      'Bucket': 'ai2-semanticscholar-cord-1',
      'Key': '2020-03-13/all_sources_metadata_2020-03-13.csv'
    }
bucket = s3.Bucket('hids511final')
bucket.copy(copy_source, 'all_sources_metadata_2020-03-13.csv')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-24-019a4826a980> in <module>
#       5     }
#       6 bucket = s3.Bucket('hids511final')
# ----> 7 bucket.copy(copy_source, 'all_sources_metadata_2020-03-13.csv')
#
# ~/miniconda/lib/python3.7/site-packages/boto3/s3/inject.py in bucket_copy(self, CopySource, Key, ExtraArgs, Callback, SourceClient, Config)
#     429     return self.meta.client.copy(
#     430         CopySource=CopySource, Bucket=self.name, Key=Key, ExtraArgs=ExtraArgs,
# --> 431         Callback=Callback, SourceClient=SourceClient, Config=Config)
#     432
#     433
#
# ~/miniconda/lib/python3.7/site-packages/boto3/s3/inject.py in copy(self, CopySource, Bucket, Key, ExtraArgs, Callback, SourceClient, Config)
#     377             extra_args=ExtraArgs, subscribers=subscribers,
#     378             source_client=SourceClient)
# --> 379         return future.result()
#     380
#     381
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/tasks.py in _main(self, transfer_future, **kwargs)
#     253             # Call the submit method to start submitting tasks to execute the
#     254             # transfer.
# --> 255             self._submit(transfer_future=transfer_future, **kwargs)
#     256         except BaseException as e:
#     257             # If there was an exception raised during the submission of task
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/copies.py in _submit(self, client, config, osutil, request_executor, transfer_future)
#     109
#     110             response = call_args.source_client.head_object(
# --> 111                 **head_object_request)
#     112             transfer_future.meta.provide_transfer_size(
#     113                 response['ContentLength'])
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found

# %%
import boto3
s3 = boto3.resource('s3')
copy_source = {
      'Bucket': 'ai2-semanticscholar-cord-1',
      'Key': '2020-03-13/all_sources_metadata_2020-03-13.csv'
    }
s3.meta.client.copy(copy_source, 'hids511final', 'all_sources_metadata_2020-03-13.csv')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-25-ca767f7704ed> in <module>
#       5       'Key': '2020-03-13/all_sources_metadata_2020-03-13.csv'
#       6     }
# ----> 7 s3.meta.client.copy(copy_source, 'hids511final', 'all_sources_metadata_2020-03-13.csv')
#
# ~/miniconda/lib/python3.7/site-packages/boto3/s3/inject.py in copy(self, CopySource, Bucket, Key, ExtraArgs, Callback, SourceClient, Config)
#     377             extra_args=ExtraArgs, subscribers=subscribers,
#     378             source_client=SourceClient)
# --> 379         return future.result()
#     380
#     381
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/tasks.py in _main(self, transfer_future, **kwargs)
#     253             # Call the submit method to start submitting tasks to execute the
#     254             # transfer.
# --> 255             self._submit(transfer_future=transfer_future, **kwargs)
#     256         except BaseException as e:
#     257             # If there was an exception raised during the submission of task
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/copies.py in _submit(self, client, config, osutil, request_executor, transfer_future)
#     109
#     110             response = call_args.source_client.head_object(
# --> 111                 **head_object_request)
#     112             transfer_future.meta.provide_transfer_size(
#     113                 response['ContentLength'])
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found

# %%
s3_resource = boto3.resource('s3')
copy_source = {
      'Bucket': 'ai2-semanticscholar-cord-1',
      'Key': '2020-03-13/all_sources_metadata_2020-03-13.csv'
    }
bucket = s3_resource.Bucket('hids511final')
bucket.copy(copy_source, 'all_sources_metadata_2020-03-13.csv')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-39-8f3881399b15> in <module>
#       5     }
#       6 bucket = s3_resource.Bucket('hids511final')
# ----> 7 bucket.copy(copy_source, 'all_sources_metadata_2020-03-13.csv')
#
# ~/miniconda/lib/python3.7/site-packages/boto3/s3/inject.py in bucket_copy(self, CopySource, Key, ExtraArgs, Callback, SourceClient, Config)
#     429     return self.meta.client.copy(
#     430         CopySource=CopySource, Bucket=self.name, Key=Key, ExtraArgs=ExtraArgs,
# --> 431         Callback=Callback, SourceClient=SourceClient, Config=Config)
#     432
#     433
#
# ~/miniconda/lib/python3.7/site-packages/boto3/s3/inject.py in copy(self, CopySource, Bucket, Key, ExtraArgs, Callback, SourceClient, Config)
#     377             extra_args=ExtraArgs, subscribers=subscribers,
#     378             source_client=SourceClient)
# --> 379         return future.result()
#     380
#     381
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/tasks.py in _main(self, transfer_future, **kwargs)
#     253             # Call the submit method to start submitting tasks to execute the
#     254             # transfer.
# --> 255             self._submit(transfer_future=transfer_future, **kwargs)
#     256         except BaseException as e:
#     257             # If there was an exception raised during the submission of task
#
# ~/miniconda/lib/python3.7/site-packages/s3transfer/copies.py in _submit(self, client, config, osutil, request_executor, transfer_future)
#     109
#     110             response = call_args.source_client.head_object(
# --> 111                 **head_object_request)
#     112             transfer_future.meta.provide_transfer_size(
#     113                 response['ContentLength'])
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found

# %%
count= 0
for page in tqdm(pages):
    count = count+1
# Out:
# 2591it [12:52,  3.35it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-39e6dcdfb64b> in <module>
#       1 count= 0
# ----> 2 for page in tqdm(pages):
#       3     count = count+1
#
# ~/miniconda/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# ~/miniconda/lib/python3.7/site-packages/botocore/paginate.py in __iter__(self)
#     253         self._inject_starting_params(current_kwargs)
#     254         while True:
# --> 255             response = self._make_request(current_kwargs)
#     256             parsed = self._extract_parsed_response(response)
#     257             if first_request:
#
# ~/miniconda/lib/python3.7/site-packages/botocore/paginate.py in _make_request(self, current_kwargs)
#     330
#     331     def _make_request(self, current_kwargs):
# --> 332         return self._method(**current_kwargs)
#     333
#     334     def _extract_parsed_response(self, response):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     661         else:
#     662             http, parsed_response = self._make_request(
# --> 663                 operation_model, request_dict, request_context)
#     664
#     665         self.meta.events.emit(
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     680     def _make_request(self, operation_model, request_dict, request_context):
#     681         try:
# --> 682             return self._endpoint.make_request(operation_model, request_dict)
#     683         except Exception as e:
#     684             self.meta.events.emit(
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
# --> 135             request, operation_model, context)
#     136         while self._needs_retry(attempts, operation_model, request_dict,
#     137                                 success_response, exception):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     165         # If no exception occurs then exception is None.
#     166         success_response, exception = self._do_get_response(
# --> 167             request, operation_model)
#     168         kwargs_to_emit = {
#     169             'response_dict': None,
#
# ~/miniconda/lib/python3.7/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model)
#     216         parser = self._response_parser_factory.create_parser(protocol)
#     217         parsed_response = parser.parse(
# --> 218             response_dict, operation_model.output_shape)
#     219         # Do a second parsing pass to pick up on any modeled error fields
#     220         # NOTE: Ideally, we would push this down into the parser classes but
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in parse(self, response, shape)
#     243                 parsed = self._do_error_parse(response, shape)
#     244         else:
# --> 245             parsed = self._do_parse(response, shape)
#     246
#     247         # We don't want to decorate event stream responses with metadata
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _do_parse(self, response, shape)
#     807         final_parsed['ResponseMetadata'] = self._populate_response_metadata(
#     808             response)
# --> 809         self._add_modeled_parse(response, shape, final_parsed)
#     810         return final_parsed
#     811
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _add_modeled_parse(self, response, shape, final_parsed)
#     816         self._parse_non_payload_attrs(response, shape,
#     817                                       member_shapes, final_parsed)
# --> 818         self._parse_payload(response, shape, member_shapes, final_parsed)
#     819
#     820     def _do_modeled_error_parse(self, response, shape):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _parse_payload(self, response, shape, member_shapes, final_parsed)
#     857         else:
#     858             original_parsed = self._initial_body_parse(response['body'])
# --> 859             body_parsed = self._parse_shape(shape, original_parsed)
#     860             final_parsed.update(body_parsed)
#     861
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     310         handler = getattr(self, '_handle_%s' % shape.type_name,
#     311                           self._default_handle)
# --> 312         return handler(shape, node)
#     313
#     314     def _handle_list(self, shape, node):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _handle_structure(self, shape, node)
#     387             if member_node is not None:
#     388                 parsed[member_name] = self._parse_shape(
# --> 389                     member_shape, member_node)
#     390             elif member_shape.serialization.get('xmlAttribute'):
#     391                 attribs = {}
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     310         handler = getattr(self, '_handle_%s' % shape.type_name,
#     311                           self._default_handle)
# --> 312         return handler(shape, node)
#     313
#     314     def _handle_list(self, shape, node):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _handle_list(self, shape, node)
#     368         if shape.serialization.get('flattened') and not isinstance(node, list):
#     369             node = [node]
# --> 370         return super(BaseXMLResponseParser, self)._handle_list(shape, node)
#     371
#     372     def _handle_structure(self, shape, node):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _handle_list(self, shape, node)
#     318         member_shape = shape.member
#     319         for item in node:
# --> 320             parsed.append(self._parse_shape(member_shape, item))
#     321         return parsed
#     322
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     310         handler = getattr(self, '_handle_%s' % shape.type_name,
#     311                           self._default_handle)
# --> 312         return handler(shape, node)
#     313
#     314     def _handle_list(self, shape, node):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _handle_structure(self, shape, node)
#     387             if member_node is not None:
#     388                 parsed[member_name] = self._parse_shape(
# --> 389                     member_shape, member_node)
#     390             elif member_shape.serialization.get('xmlAttribute'):
#     391                 attribs = {}
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     310         handler = getattr(self, '_handle_%s' % shape.type_name,
#     311                           self._default_handle)
# --> 312         return handler(shape, node)
#     313
#     314     def _handle_list(self, shape, node):
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _get_text_content(self, shape, node_or_string)
#     172         else:
#     173             text = node_or_string
# --> 174         return func(self, shape, text)
#     175     return _get_text_content
#     176
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _handle_string(self, shape, text)
#    1008     @_text_content
#    1009     def _handle_string(self, shape, text):
# -> 1010         text = super(RestXMLParser, self)._handle_string(shape, text)
#    1011         return text
#    1012
#
# ~/miniconda/lib/python3.7/site-packages/botocore/parsers.py in _handle_string(self, shape, value)
#     902     def _handle_string(self, shape, value):
#     903         parsed = value
# --> 904         if is_json_value_header(shape):
#     905             decoded = base64.b64decode(value).decode(self.DEFAULT_ENCODING)
#     906             parsed = json.loads(decoded)
#
# KeyboardInterrupt:

# %%
count
